# %% [markdown]
# # EcoHome Energy Advisor - Agent Run & Evaluation
#
# In this notebook, you'll run the Energy Advisor agent with various real-world scenarios and see how it helps customers optimize their energy usage.
#
# ## Learning Objectives
# - Create the agent's instructions
# - Run the Energy Advisor with different types of questions
# - Evaluate response quality and accuracy
# - Measure tool usage effectiveness
# - Identify areas for improvement
# - Implement evaluation metrics
#
# ## Evaluation Criteria
# - **Accuracy**: Correct information and calculations
# - **Relevance**: Responses address the user's question
# - **Completeness**: Comprehensive answers with actionable advice
# - **Tool Usage**: Appropriate use of available tools
# - **Reasoning**: Clear explanation of recommendations

# %% [markdown]
# ## 1. Import and Initialize

# %%
from datetime import datetime
from agent import Agent

# %%
ECOHOME_SYSTEM_PROMPT = """You are EcoHome Energy Advisor, an expert assistant for smart-home energy optimization.

Your goals:
1. Reduce user electricity cost while keeping comfort and practicality.
2. Reduce carbon impact by prioritizing solar generation and lower-demand periods.
3. Provide clear, actionable recommendations with concrete times and expected tradeoffs.

Rules:
- Use tools whenever recommendations depend on weather, prices, historical usage, or savings math.
- Prefer specific schedules (hours/time windows), not vague guidance.
- If data is missing, state assumptions explicitly.
- Include brief reasoning: why this schedule is better.
- Include estimated savings when possible.
- Keep answers concise and practical.

When relevant, optimize around:
- EV charging
- Thermostat/HVAC operation
- Appliance scheduling (dishwasher, laundry, water heater)
- Solar self-consumption and grid export/import balance

If the user asks for multiple options, provide a ranked list with pros/cons."""

# %%
ecohome_agent = Agent(
    instructions=ECOHOME_SYSTEM_PROMPT,
)

# %%
response = ecohome_agent.invoke(
    question="When should I charge my electric car tomorrow to minimize cost and maximize solar power?",
    context="Location: San Francisco, CA"
)

# %%
print(response["messages"][-1].content)
# Out:
# To minimize costs and maximize solar power for charging your electric vehicle (EV) tomorrow (October 7, 2023), follow this schedule:
#
# ### Recommended Charging Time:
# - **Charge your EV from 11:00 AM to 2:00 PM.**
#
# ### Reasoning:
# 1. **Solar Generation**:
#    - Solar irradiance peaks around 11:00 AM to 2:00 PM, with the highest value at 11:00 AM (833.3 W/m²). This means your solar panels will generate the most energy during this time, allowing you to use solar power for charging.
#
# 2. **Electricity Rates**:
#    - The electricity rates during this time are as follows:
#      - **11:00 AM**: $0.1472 (mid-peak)
#      - **12:00 PM**: $0.1313 (mid-peak)
#      - **1:00 PM**: $0.1438 (mid-peak)
#      - **2:00 PM**: $0.1385 (mid-peak)
#    - While these rates are mid-peak, they are still lower than the peak rates that occur later in the day (up to $0.2104).
#
# ### Expected Tradeoffs:
# - Charging during this window will utilize solar energy, reducing reliance on grid electricity and potentially lowering your overall electricity costs.
# - The rates are higher than off-peak rates, but the benefit of using solar energy outweighs the cost difference.
#
# ### Estimated Savings:
# - If you charge your EV during this time using solar energy, you can significantly reduce your carbon footprint and electricity costs compared to charging during peak hours (4 PM - 7 PM), where rates exceed $0.20 per kWh.
#
# By following this schedule, you will optimize your EV charging for both cost and sustainability.

# %%
print("TOOLS:")
for msg in response["messages"]:
    obj = msg.model_dump()
    if obj.get("tool_call_id"):
        print("-", msg.name)
# Out:
# TOOLS:
# - get_weather_forecast
# - get_electricity_prices

# %% [markdown]
# ## 2. Define Test Cases

# %%
# Test cases covering EV, thermostat, appliances, solar, and savings scenarios.

# %%
test_cases = [
    {
        "id": "ev_charging_1",
        "question": "When should I charge my electric car tomorrow to minimize cost and maximize solar power?",
        "expected_tools": ["get_weather_forecast", "get_electricity_prices"],
        "expected_response": "The response should contain time recommendation, cost analysis and solar consideration",
    },
    {
        "id": "ev_charging_2",
        "question": "I need 30 kWh for my EV by 7 AM. What is the cheapest charging schedule tonight?",
        "expected_tools": ["get_electricity_prices", "calculate_energy_savings"],
        "expected_response": "The response should include overnight off-peak timing and cost estimate",
    },
    {
        "id": "thermostat_1",
        "question": "What thermostat setting should I use Wednesday afternoon if prices spike?",
        "expected_tools": ["get_electricity_prices", "get_weather_forecast"],
        "expected_response": "The response should include temperature setpoint strategy and peak pricing avoidance",
    },
    {
        "id": "thermostat_2",
        "question": "How can I pre-cool my home to reduce HVAC costs during evening peak hours?",
        "expected_tools": ["get_electricity_prices", "get_weather_forecast"],
        "expected_response": "The response should include pre-cooling window, peak-hour behavior, and comfort tradeoff",
    },
    {
        "id": "appliance_1",
        "question": "When should I run my dishwasher and laundry tomorrow for the lowest bill?",
        "expected_tools": ["get_electricity_prices"],
        "expected_response": "The response should recommend specific off-peak times for both appliances",
    },
    {
        "id": "appliance_2",
        "question": "I can run my water heater for only 3 hours today. Which hours are best?",
        "expected_tools": ["get_electricity_prices"],
        "expected_response": "The response should include a 3-hour schedule based on low prices",
    },
    {
        "id": "solar_1",
        "question": "What is the best time tomorrow to run heavy loads to use maximum solar generation?",
        "expected_tools": ["get_weather_forecast"],
        "expected_response": "The response should identify midday solar window and suitable loads",
    },
    {
        "id": "solar_2",
        "question": "Should I delay EV charging to noon tomorrow if it is sunny?",
        "expected_tools": ["get_weather_forecast", "get_electricity_prices"],
        "expected_response": "The response should compare solar availability vs electricity rates",
    },
    {
        "id": "history_1",
        "question": "Based on my last 7 days of usage, what are 3 ways to reduce consumption?",
        "expected_tools": ["query_energy_usage", "search_energy_tips"],
        "expected_response": "The response should reference usage patterns and provide 3 actionable recommendations",
    },
    {
        "id": "savings_1",
        "question": "How much can I save if I reduce HVAC use from 18 kWh/day to 14 kWh/day?",
        "expected_tools": ["calculate_energy_savings"],
        "expected_response": "The response should include daily and annual savings estimates",
    },
]

if len(test_cases) < 10:
    raise ValueError("You MUST have at least 10 test cases")

# %% [markdown]
# ## 3. Run Agent Tests

# %%
CONTEXT = "Location: San Francisco, CA"

# %%
# Run the agent tests
# For each test case, call the agent and collect the response
# Store results for evaluation

print("=== Running Agent Tests ===")
test_results = []

for i, test_case in enumerate(test_cases):
    print(f"\nTest {i+1}: {test_case['id']}")
    print(f"Question: {test_case['question']}")
    print("-" * 50)
    
    try:
        # Call the agent
        response = ecohome_agent.invoke(
            question=test_case['question'],
            context=CONTEXT
        )
        
        # Store the result
        result = {
            'test_id': test_case['id'],
            'question': test_case['question'],
            'response': response,
            'expected_tools': test_case['expected_tools'],
            'expected_response': test_case['expected_response'],
            'timestamp': datetime.now().isoformat()
        }
        test_results.append(result)
                
    except Exception as e:
        print(f"Error: {e}")
        result = {
            'test_id': test_case['id'],
            'question': test_case['question'],
            'response': f"Error: {str(e)}",
            'expected_tools': test_case['expected_tools'],
            'expected_response': test_case['expected_response'],
            'timestamp': datetime.now().isoformat(),
            'error': str(e)
        }
        test_results.append(result)

print(f"\nCompleted {len(test_results)} tests")
# Out:
# === Running Agent Tests ===
#
# Test 1: ev_charging_1
# Question: When should I charge my electric car tomorrow to minimize cost and maximize solar power?
# --------------------------------------------------
#
# Test 2: ev_charging_2
# Question: I need 30 kWh for my EV by 7 AM. What is the cheapest charging schedule tonight?
# --------------------------------------------------
#
# Test 3: thermostat_1
# Question: What thermostat setting should I use Wednesday afternoon if prices spike?
# --------------------------------------------------
#
# Test 4: thermostat_2
# Question: How can I pre-cool my home to reduce HVAC costs during evening peak hours?
# --------------------------------------------------
#
# Test 5: appliance_1
# Question: When should I run my dishwasher and laundry tomorrow for the lowest bill?
# --------------------------------------------------
#
# Test 6: appliance_2
# Question: I can run my water heater for only 3 hours today. Which hours are best?
# --------------------------------------------------
#
# Test 7: solar_1
# Question: What is the best time tomorrow to run heavy loads to use maximum solar generation?
# --------------------------------------------------
#
# Test 8: solar_2
# Question: Should I delay EV charging to noon tomorrow if it is sunny?
# --------------------------------------------------
#
# Test 9: history_1
# Question: Based on my last 7 days of usage, what are 3 ways to reduce consumption?
# --------------------------------------------------
#
# Test 10: savings_1
# Question: How much can I save if I reduce HVAC use from 18 kWh/day to 14 kWh/day?
# --------------------------------------------------
#
# Completed 10 tests

# %%
test_results
# Out:
# [{'test_id': 'ev_charging_1',
#   'question': 'When should I charge my electric car tomorrow to minimize cost and maximize solar power?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='79a7fee3-3d8a-46f1-a9f3-cea2fa457c9d'),
#     HumanMessage(content='When should I charge my electric car tomorrow to minimize cost and maximize solar power?', additional_kwargs={}, response_metadata={}, id='e17a9b66-768e-431f-bd0d-e53c6f806f3f'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 1048, 'total_tokens': 1109, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_bd4be55b21', 'id': 'chatcmpl-DAHu03zu6YglUUZki6qCAxiaPjE1R', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c5b-91e8-7dc1-aba2-636cd427c50b-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 1}, 'id': 'call_qbfEWWANXSpQtwc7UPyxkAAm', 'type': 'tool_call'}, {'name': 'get_electricity_prices', 'args': {'date': '2023-10-07'}, 'id': 'call_5wBjRWsly1L0jy7ksGF6aRnn', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1048, 'output_tokens': 61, 'total_tokens': 1109, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"location": "San Francisco, CA", "forecast_days": 1, "current": {"temperature_c": 13.9, "condition": "sunny", "humidity": 51.6, "wind_speed": 6.8}, "hourly": [{"day": 1, "hour": 0, "temperature_c": 11.4, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 69.6, "wind_speed": 15.4}, {"day": 1, "hour": 1, "temperature_c": 9.7, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 78.4, "wind_speed": 7.1}, {"day": 1, "hour": 2, "temperature_c": 10.1, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 45.6, "wind_speed": 14.5}, {"day": 1, "hour": 3, "temperature_c": 10.1, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 62.9, "wind_speed": 12.2}, {"day": 1, "hour": 4, "temperature_c": 9.3, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 33.1, "wind_speed": 13.4}, {"day": 1, "hour": 5, "temperature_c": 11.9, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 47.7, "wind_speed": 7.9}, {"day": 1, "hour": 6, "temperature_c": 8.3, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 47.9, "wind_speed": 9.5}, {"day": 1, "hour": 7, "temperature_c": 11.4, "condition": "sunny", "solar_irradiance": 166.7, "humidity": 31.5, "wind_speed": 8.1}, {"day": 1, "hour": 8, "temperature_c": 12.5, "condition": "sunny", "solar_irradiance": 333.3, "humidity": 47.8, "wind_speed": 8.9}, {"day": 1, "hour": 9, "temperature_c": 13.8, "condition": "partly_cloudy", "solar_irradiance": 350.0, "humidity": 41.0, "wind_speed": 19.4}, {"day": 1, "hour": 10, "temperature_c": 12.6, "condition": "sunny", "solar_irradiance": 666.7, "humidity": 57.9, "wind_speed": 13.9}, {"day": 1, "hour": 11, "temperature_c": 16.3, "condition": "sunny", "solar_irradiance": 833.3, "humidity": 61.5, "wind_speed": 19.9}, {"day": 1, "hour": 12, "temperature_c": 14.4, "condition": "sunny", "solar_irradiance": 1000.0, "humidity": 46.9, "wind_speed": 11.6}, {"day": 1, "hour": 13, "temperature_c": 15.2, "condition": "partly_cloudy", "solar_irradiance": 583.3, "humidity": 61.3, "wind_speed": 18.8}, {"day": 1, "hour": 14, "temperature_c": 14.4, "condition": "partly_cloudy", "solar_irradiance": 466.7, "humidity": 47.6, "wind_speed": 3.2}, {"day": 1, "hour": 15, "temperature_c": 13.1, "condition": "cloudy", "solar_irradiance": 175.0, "humidity": 36.8, "wind_speed": 3.4}, {"day": 1, "hour": 16, "temperature_c": 10.3, "condition": "sunny", "solar_irradiance": 333.3, "humidity": 74.8, "wind_speed": 6.4}, {"day": 1, "hour": 17, "temperature_c": 12.2, "condition": "partly_cloudy", "solar_irradiance": 116.7, "humidity": 47.3, "wind_speed": 18.2}, {"day": 1, "hour": 18, "temperature_c": 9.1, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 54.6, "wind_speed": 16.5}, {"day": 1, "hour": 19, "temperature_c": 10.9, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 37.6, "wind_speed": 16.4}, {"day": 1, "hour": 20, "temperature_c": 8.0, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 68.8, "wind_speed": 14.3}, {"day": 1, "hour": 21, "temperature_c": 10.9, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 41.2, "wind_speed": 4.2}, {"day": 1, "hour": 22, "temperature_c": 10.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 71.9, "wind_speed": 12.1}, {"day": 1, "hour": 23, "temperature_c": 9.0, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 71.0, "wind_speed": 3.6}]}', name='get_weather_forecast', id='b7e0a957-ed3e-455d-9bd1-2ba3401831cd', tool_call_id='call_qbfEWWANXSpQtwc7UPyxkAAm'),
#     ToolMessage(content='{"date": "2023-10-07", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.113, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.1128, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.1019, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.1072, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.1116, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.1038, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.1459, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 7, "rate": 0.1374, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 8, "rate": 0.1499, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 9, "rate": 0.1494, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 10, "rate": 0.1303, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 11, "rate": 0.1497, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 12, "rate": 0.1412, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 13, "rate": 0.1302, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 14, "rate": 0.1497, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 15, "rate": 0.1486, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 16, "rate": 0.1985, "period": "peak", "demand_charge": 0.04}, {"hour": 17, "rate": 0.1935, "period": "peak", "demand_charge": 0.04}, {"hour": 18, "rate": 0.2025, "period": "peak", "demand_charge": 0.04}, {"hour": 19, "rate": 0.2113, "period": "peak", "demand_charge": 0.04}, {"hour": 20, "rate": 0.2011, "period": "peak", "demand_charge": 0.04}, {"hour": 21, "rate": 0.193, "period": "peak", "demand_charge": 0.04}, {"hour": 22, "rate": 0.1127, "period": "off_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.1178, "period": "off_peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='98284642-19a8-4b01-aa42-87999c1dc9d8', tool_call_id='call_5wBjRWsly1L0jy7ksGF6aRnn'),
#     AIMessage(content='To minimize costs and maximize solar power for charging your electric vehicle (EV) tomorrow (October 7, 2023), follow this schedule:\n\n### Recommended Charging Time:\n- **Charge your EV from 12:00 PM to 2:00 PM.**\n\n### Reasoning:\n1. **Solar Generation Peak**: Solar irradiance is highest around noon, peaking at 1000 W/m² at 12 PM. This means your solar panels will generate the most energy during this time, allowing you to use more solar power for charging.\n2. **Electricity Rates**: The electricity rate during this time is **$0.1412 per kWh**, which is lower than the peak rates that occur later in the afternoon and evening.\n\n### Expected Tradeoffs:\n- Charging during this window will utilize solar energy, reducing reliance on grid electricity and lowering your overall electricity costs.\n- If you charge later (after 2 PM), you may face higher rates (up to $0.1985 per kWh during peak hours).\n\n### Summary of Rates:\n- **12 PM - 1 PM**: $0.1412 (mid-peak)\n- **1 PM - 2 PM**: $0.1302 (mid-peak)\n\nBy charging during this optimal window, you can maximize your solar energy usage and minimize costs.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 274, 'prompt_tokens': 3365, 'total_tokens': 3639, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_bd4be55b21', 'id': 'chatcmpl-DAHu2FDELuh0mqL2XvPPUaKcbWOFK', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c5b-9aca-7a23-946c-6156ac820dd3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3365, 'output_tokens': 274, 'total_tokens': 3639, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_weather_forecast', 'get_electricity_prices'],
#   'expected_response': 'The response should contain time recommendation, cost analysis and solar consideration',
#   'timestamp': '2026-02-17T17:07:55.051889'},
#  {'test_id': 'ev_charging_2',
#   'question': 'I need 30 kWh for my EV by 7 AM. What is the cheapest charging schedule tonight?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='7efefc2c-980d-4fe4-b74e-6aba5df023a9'),
#     HumanMessage(content='I need 30 kWh for my EV by 7 AM. What is the cheapest charging schedule tonight?', additional_kwargs={}, response_metadata={}, id='4355d203-50c8-4848-8cfc-3ff6f93a2eb4'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 1054, 'total_tokens': 1067, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_bd4be55b21', 'id': 'chatcmpl-DAHu9KurGbuSnfLQUfhRjY17dqysK', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c5b-b3af-7901-919b-93ff1f102730-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {}, 'id': 'call_FTHEGn41rvoxuS0TiEaQAlmj', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1054, 'output_tokens': 13, 'total_tokens': 1067, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"date": "2026-02-17", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.1078, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.0957, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.1136, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.1025, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.1074, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.1149, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.1325, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 7, "rate": 0.1382, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 8, "rate": 0.1354, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 9, "rate": 0.1349, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 10, "rate": 0.131, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 11, "rate": 0.1334, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 12, "rate": 0.1441, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 13, "rate": 0.1402, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 14, "rate": 0.1347, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 15, "rate": 0.1406, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 16, "rate": 0.2079, "period": "peak", "demand_charge": 0.04}, {"hour": 17, "rate": 0.1953, "period": "peak", "demand_charge": 0.04}, {"hour": 18, "rate": 0.2019, "period": "peak", "demand_charge": 0.04}, {"hour": 19, "rate": 0.2051, "period": "peak", "demand_charge": 0.04}, {"hour": 20, "rate": 0.2116, "period": "peak", "demand_charge": 0.04}, {"hour": 21, "rate": 0.2096, "period": "peak", "demand_charge": 0.04}, {"hour": 22, "rate": 0.1277, "period": "off_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.1254, "period": "off_peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='993be730-bb11-4be5-a27a-28c6c11f47b3', tool_call_id='call_FTHEGn41rvoxuS0TiEaQAlmj'),
#     AIMessage(content='To charge your EV with 30 kWh by 7 AM, the optimal charging schedule tonight is as follows:\n\n### Recommended Charging Schedule:\n- **11 PM - 12 AM**: Charge 10 kWh at **$0.1254/kWh** (off-peak)\n- **12 AM - 1 AM**: Charge 10 kWh at **$0.0957/kWh** (off-peak)\n- **1 AM - 2 AM**: Charge 10 kWh at **$0.1136/kWh** (off-peak)\n\n### Total Cost Calculation:\n- **11 PM - 12 AM**: 10 kWh * $0.1254 = $1.254\n- **12 AM - 1 AM**: 10 kWh * $0.0957 = $0.957\n- **1 AM - 2 AM**: 10 kWh * $0.1136 = $1.136\n\n### Total Cost: \n- **$1.254 + $0.957 + $1.136 = $3.347**\n\n### Reasoning:\n- Charging during off-peak hours (11 PM - 6 AM) takes advantage of the lowest rates, especially the hour from 12 AM to 1 AM, which is the cheapest at $0.0957/kWh.\n\nThis schedule ensures you have the required 30 kWh charged by 7 AM at the lowest possible cost.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 302, 'prompt_tokens': 1883, 'total_tokens': 2185, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_bd4be55b21', 'id': 'chatcmpl-DAHuAicvyUpwGzHHq9lwCv2fqdNRD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c5b-b998-73a1-9ddf-93ac81a34b3e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1883, 'output_tokens': 302, 'total_tokens': 2185, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_electricity_prices', 'calculate_energy_savings'],
#   'expected_response': 'The response should include overnight off-peak timing and cost estimate',
#   'timestamp': '2026-02-17T17:08:03.687498'},
#  {'test_id': 'thermostat_1',
#   'question': 'What thermostat setting should I use Wednesday afternoon if prices spike?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='33d16856-f38f-476c-a1b3-1aba3ff7dbcc'),
#     HumanMessage(content='What thermostat setting should I use Wednesday afternoon if prices spike?', additional_kwargs={}, response_metadata={}, id='9c8a9721-41c7-4077-9059-25b28dd48911'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 1044, 'total_tokens': 1066, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_bd4be55b21', 'id': 'chatcmpl-DAHuHJjYS2JZBGi2g6LTdjPeTpRX5', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c5b-d568-7223-83a4-4d80ee1738f6-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {'date': '2023-11-01'}, 'id': 'call_xn9AqRLO7aQFxGgDUdgUO0bR', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1044, 'output_tokens': 22, 'total_tokens': 1066, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"date": "2023-11-01", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.1145, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.1062, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.1049, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.1052, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.1072, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.1106, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.1381, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 7, "rate": 0.1475, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 8, "rate": 0.1445, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 9, "rate": 0.1409, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 10, "rate": 0.1408, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 11, "rate": 0.1442, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 12, "rate": 0.1371, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 13, "rate": 0.1466, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 14, "rate": 0.1415, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 15, "rate": 0.1446, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 16, "rate": 0.1941, "period": "peak", "demand_charge": 0.04}, {"hour": 17, "rate": 0.1939, "period": "peak", "demand_charge": 0.04}, {"hour": 18, "rate": 0.2008, "period": "peak", "demand_charge": 0.04}, {"hour": 19, "rate": 0.2106, "period": "peak", "demand_charge": 0.04}, {"hour": 20, "rate": 0.1942, "period": "peak", "demand_charge": 0.04}, {"hour": 21, "rate": 0.1981, "period": "peak", "demand_charge": 0.04}, {"hour": 22, "rate": 0.1163, "period": "off_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.1135, "period": "off_peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='9239681c-00f4-4129-a1e6-081aed3e1716', tool_call_id='call_xn9AqRLO7aQFxGgDUdgUO0bR'),
#     AIMessage(content="On Wednesday, November 1st, the electricity prices spike during the peak hours from 4 PM to 8 PM. Here are the specific rates:\n\n- **4 PM - 5 PM**: $0.1941/kWh\n- **5 PM - 6 PM**: $0.1939/kWh\n- **6 PM - 7 PM**: $0.2008/kWh\n- **7 PM - 8 PM**: $0.2106/kWh\n\n### Recommended Thermostat Setting:\n- **Set your thermostat to a higher temperature (e.g., 78°F or higher)** during these peak hours to reduce cooling demand. \n\n### Reasoning:\n- By raising the temperature, you can minimize the use of your HVAC system during the most expensive hours, thus saving on electricity costs.\n\n### Expected Tradeoffs:\n- You may experience slightly less comfort during the hottest part of the day, but this can be mitigated by cooling the home before peak hours (e.g., from 2 PM to 4 PM when rates are lower).\n\n### Estimated Savings:\n- If your HVAC system typically runs for 2 hours during peak hours, raising the temperature could save you approximately $5-$10, depending on your system's efficiency and usage patterns. \n\nConsider pre-cooling your home before the peak hours to maintain comfort while saving on costs.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 280, 'prompt_tokens': 1883, 'total_tokens': 2163, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_bd4be55b21', 'id': 'chatcmpl-DAHuJK7eJifDMQYOHgELvag5aP0in', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c5b-de74-7970-9252-1393ec01a715-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1883, 'output_tokens': 280, 'total_tokens': 2163, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_electricity_prices', 'get_weather_forecast'],
#   'expected_response': 'The response should include temperature setpoint strategy and peak pricing avoidance',
#   'timestamp': '2026-02-17T17:08:13.204918'},
#  {'test_id': 'thermostat_2',
#   'question': 'How can I pre-cool my home to reduce HVAC costs during evening peak hours?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='5e452f35-c5c0-42a5-a765-0c568ca66def'),
#     HumanMessage(content='How can I pre-cool my home to reduce HVAC costs during evening peak hours?', additional_kwargs={}, response_metadata={}, id='2135a82b-b26f-4ecf-99ee-c81517934950'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 1049, 'total_tokens': 1103, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_bd4be55b21', 'id': 'chatcmpl-DAHuR7RNvRissMlX8HwtDkieLJTPL', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c5b-fa96-71f1-a5b2-264730aa995b-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 1}, 'id': 'call_rYLXMu7bRjX38laliy46otTP', 'type': 'tool_call'}, {'name': 'get_electricity_prices', 'args': {}, 'id': 'call_XmtGzFfRNKC5pTKUlyhvtu5g', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1049, 'output_tokens': 54, 'total_tokens': 1103, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"location": "San Francisco, CA", "forecast_days": 1, "current": {"temperature_c": 13.3, "condition": "partly_cloudy", "humidity": 56.2, "wind_speed": 12.4}, "hourly": [{"day": 1, "hour": 0, "temperature_c": 11.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 36.5, "wind_speed": 3.0}, {"day": 1, "hour": 1, "temperature_c": 9.7, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 74.9, "wind_speed": 8.4}, {"day": 1, "hour": 2, "temperature_c": 11.9, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 66.7, "wind_speed": 4.3}, {"day": 1, "hour": 3, "temperature_c": 10.5, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 70.1, "wind_speed": 11.5}, {"day": 1, "hour": 4, "temperature_c": 9.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 51.9, "wind_speed": 18.6}, {"day": 1, "hour": 5, "temperature_c": 9.9, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 60.0, "wind_speed": 12.3}, {"day": 1, "hour": 6, "temperature_c": 8.5, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 68.3, "wind_speed": 15.0}, {"day": 1, "hour": 7, "temperature_c": 11.9, "condition": "partly_cloudy", "solar_irradiance": 116.7, "humidity": 59.0, "wind_speed": 10.7}, {"day": 1, "hour": 8, "temperature_c": 11.8, "condition": "cloudy", "solar_irradiance": 116.7, "humidity": 63.6, "wind_speed": 3.5}, {"day": 1, "hour": 9, "temperature_c": 11.9, "condition": "sunny", "solar_irradiance": 500.0, "humidity": 54.0, "wind_speed": 2.8}, {"day": 1, "hour": 10, "temperature_c": 12.6, "condition": "sunny", "solar_irradiance": 666.7, "humidity": 67.6, "wind_speed": 8.9}, {"day": 1, "hour": 11, "temperature_c": 14.7, "condition": "partly_cloudy", "solar_irradiance": 583.3, "humidity": 57.1, "wind_speed": 19.1}, {"day": 1, "hour": 12, "temperature_c": 14.1, "condition": "cloudy", "solar_irradiance": 350.0, "humidity": 63.7, "wind_speed": 13.5}, {"day": 1, "hour": 13, "temperature_c": 15.1, "condition": "cloudy", "solar_irradiance": 291.7, "humidity": 33.6, "wind_speed": 9.4}, {"day": 1, "hour": 14, "temperature_c": 14.0, "condition": "partly_cloudy", "solar_irradiance": 466.7, "humidity": 31.1, "wind_speed": 17.0}, {"day": 1, "hour": 15, "temperature_c": 11.5, "condition": "partly_cloudy", "solar_irradiance": 350.0, "humidity": 47.8, "wind_speed": 16.0}, {"day": 1, "hour": 16, "temperature_c": 13.0, "condition": "sunny", "solar_irradiance": 333.3, "humidity": 54.8, "wind_speed": 9.3}, {"day": 1, "hour": 17, "temperature_c": 10.6, "condition": "sunny", "solar_irradiance": 166.7, "humidity": 73.4, "wind_speed": 12.5}, {"day": 1, "hour": 18, "temperature_c": 11.9, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 44.3, "wind_speed": 8.1}, {"day": 1, "hour": 19, "temperature_c": 9.6, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 63.3, "wind_speed": 19.1}, {"day": 1, "hour": 20, "temperature_c": 9.1, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 65.7, "wind_speed": 7.6}, {"day": 1, "hour": 21, "temperature_c": 8.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 36.7, "wind_speed": 6.9}, {"day": 1, "hour": 22, "temperature_c": 11.1, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 61.6, "wind_speed": 12.2}, {"day": 1, "hour": 23, "temperature_c": 9.5, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 57.2, "wind_speed": 14.0}]}', name='get_weather_forecast', id='f51c0a8f-5d77-4a05-b72d-97fa9e887f43', tool_call_id='call_rYLXMu7bRjX38laliy46otTP'),
#     ToolMessage(content='{"date": "2026-02-17", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.0984, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.0954, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.1028, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.1069, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.0989, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.0961, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.1374, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 7, "rate": 0.1325, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 8, "rate": 0.1425, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 9, "rate": 0.145, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 10, "rate": 0.1459, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 11, "rate": 0.1318, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 12, "rate": 0.1321, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 13, "rate": 0.1465, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 14, "rate": 0.1329, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 15, "rate": 0.1418, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 16, "rate": 0.2015, "period": "peak", "demand_charge": 0.04}, {"hour": 17, "rate": 0.1987, "period": "peak", "demand_charge": 0.04}, {"hour": 18, "rate": 0.1993, "period": "peak", "demand_charge": 0.04}, {"hour": 19, "rate": 0.2048, "period": "peak", "demand_charge": 0.04}, {"hour": 20, "rate": 0.2107, "period": "peak", "demand_charge": 0.04}, {"hour": 21, "rate": 0.2013, "period": "peak", "demand_charge": 0.04}, {"hour": 22, "rate": 0.1097, "period": "off_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.111, "period": "off_peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='c03a23bf-e5d3-4293-93fe-d1dd4b2ad64b', tool_call_id='call_XmtGzFfRNKC5pTKUlyhvtu5g'),
#     AIMessage(content='To pre-cool your home and reduce HVAC costs during evening peak hours, follow this schedule:\n\n### Recommended Schedule:\n- **Pre-Cool Time:** 3 PM - 5 PM\n- **Target Temperature:** Set your thermostat to cool your home to around 72°F (22°C).\n\n### Reasoning:\n1. **Peak Pricing:** Electricity rates are highest from 4 PM to 9 PM, peaking at 6 PM - 8 PM (up to $0.2107 per kWh). Pre-cooling during the afternoon (3 PM - 5 PM) allows you to take advantage of lower rates (around $0.1069 to $0.0989 per kWh).\n2. **Temperature Management:** By cooling your home before the peak hours, you can maintain comfort without running the HVAC system as much during the peak pricing period.\n\n### Expected Tradeoffs:\n- **Increased Energy Use in Afternoon:** You will use more energy during the pre-cooling period, but it will be at a lower rate.\n- **Comfort Maintenance:** Your home will remain cooler during the peak hours, enhancing comfort.\n\n### Estimated Savings:\nAssuming your HVAC system uses about 2 kWh per hour for cooling:\n- **Cost during Pre-Cool (3 PM - 5 PM):** \n  - 2 kWh * 2 hours * $0.1069 = $0.4276\n- **Cost during Peak (6 PM - 8 PM):**\n  - 2 kWh * 3 hours * $0.2107 = $1.2624\n- **Total Cost without Pre-Cooling:** $1.2624\n- **Total Cost with Pre-Cooling:** $0.4276\n- **Estimated Savings:** $1.2624 - $0.4276 = **$0.8348** over the peak period.\n\nBy following this schedule, you can effectively manage your HVAC costs while ensuring comfort during the hottest parts of the day.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 408, 'prompt_tokens': 3366, 'total_tokens': 3774, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_bd4be55b21', 'id': 'chatcmpl-DAHuTyJrXpxac4nBMNZE3LrC2Rzqf', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c5c-0452-7251-b45b-2418c1d93530-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3366, 'output_tokens': 408, 'total_tokens': 3774, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_electricity_prices', 'get_weather_forecast'],
#   'expected_response': 'The response should include pre-cooling window, peak-hour behavior, and comfort tradeoff',
#   'timestamp': '2026-02-17T17:08:25.703243'},
#  {'test_id': 'appliance_1',
#   'question': 'When should I run my dishwasher and laundry tomorrow for the lowest bill?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='9744495f-e037-469d-9031-2c41ee912c37'),
#     HumanMessage(content='When should I run my dishwasher and laundry tomorrow for the lowest bill?', additional_kwargs={}, response_metadata={}, id='7fd047d5-d837-45dc-95b3-9496e8af77d7'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 1046, 'total_tokens': 1107, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_bd4be55b21', 'id': 'chatcmpl-DAHudEWXK8MZESXHNHvbZutV5f3tG', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c5c-2b6b-7d70-bc65-d54ea4f58214-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {'date': '2023-10-07'}, 'id': 'call_7Jdh4k9GhfPaHI32BlUtcGyQ', 'type': 'tool_call'}, {'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 1}, 'id': 'call_hg2SPayp0Y6eZQVgmKCw2lJI', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1046, 'output_tokens': 61, 'total_tokens': 1107, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"date": "2023-10-07", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.0956, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.1051, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.1142, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.0995, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.1125, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.1048, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.1306, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 7, "rate": 0.1331, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 8, "rate": 0.1402, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 9, "rate": 0.1362, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 10, "rate": 0.149, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 11, "rate": 0.1449, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 12, "rate": 0.139, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 13, "rate": 0.1328, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 14, "rate": 0.1332, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 15, "rate": 0.1447, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 16, "rate": 0.2096, "period": "peak", "demand_charge": 0.04}, {"hour": 17, "rate": 0.1959, "period": "peak", "demand_charge": 0.04}, {"hour": 18, "rate": 0.2075, "period": "peak", "demand_charge": 0.04}, {"hour": 19, "rate": 0.2081, "period": "peak", "demand_charge": 0.04}, {"hour": 20, "rate": 0.1937, "period": "peak", "demand_charge": 0.04}, {"hour": 21, "rate": 0.1948, "period": "peak", "demand_charge": 0.04}, {"hour": 22, "rate": 0.109, "period": "off_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.1232, "period": "off_peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='92ded686-1909-4f7f-b66a-d5cb6a41b885', tool_call_id='call_7Jdh4k9GhfPaHI32BlUtcGyQ'),
#     ToolMessage(content='{"location": "San Francisco, CA", "forecast_days": 1, "current": {"temperature_c": 13.7, "condition": "partly_cloudy", "humidity": 65.3, "wind_speed": 14.1}, "hourly": [{"day": 1, "hour": 0, "temperature_c": 11.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 52.1, "wind_speed": 5.3}, {"day": 1, "hour": 1, "temperature_c": 9.1, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 59.1, "wind_speed": 5.1}, {"day": 1, "hour": 2, "temperature_c": 8.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 51.7, "wind_speed": 18.3}, {"day": 1, "hour": 3, "temperature_c": 8.5, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 74.2, "wind_speed": 16.1}, {"day": 1, "hour": 4, "temperature_c": 10.7, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 40.7, "wind_speed": 3.6}, {"day": 1, "hour": 5, "temperature_c": 8.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 76.9, "wind_speed": 15.8}, {"day": 1, "hour": 6, "temperature_c": 9.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 58.9, "wind_speed": 19.8}, {"day": 1, "hour": 7, "temperature_c": 11.2, "condition": "cloudy", "solar_irradiance": 58.3, "humidity": 75.5, "wind_speed": 12.3}, {"day": 1, "hour": 8, "temperature_c": 12.2, "condition": "partly_cloudy", "solar_irradiance": 233.3, "humidity": 36.7, "wind_speed": 6.0}, {"day": 1, "hour": 9, "temperature_c": 14.8, "condition": "cloudy", "solar_irradiance": 175.0, "humidity": 61.7, "wind_speed": 5.4}, {"day": 1, "hour": 10, "temperature_c": 13.1, "condition": "partly_cloudy", "solar_irradiance": 466.7, "humidity": 63.0, "wind_speed": 3.0}, {"day": 1, "hour": 11, "temperature_c": 14.8, "condition": "partly_cloudy", "solar_irradiance": 583.3, "humidity": 75.8, "wind_speed": 18.6}, {"day": 1, "hour": 12, "temperature_c": 15.6, "condition": "cloudy", "solar_irradiance": 350.0, "humidity": 38.4, "wind_speed": 17.0}, {"day": 1, "hour": 13, "temperature_c": 16.8, "condition": "sunny", "solar_irradiance": 833.3, "humidity": 61.3, "wind_speed": 14.3}, {"day": 1, "hour": 14, "temperature_c": 15.0, "condition": "cloudy", "solar_irradiance": 233.3, "humidity": 46.5, "wind_speed": 2.5}, {"day": 1, "hour": 15, "temperature_c": 14.7, "condition": "cloudy", "solar_irradiance": 175.0, "humidity": 71.1, "wind_speed": 6.7}, {"day": 1, "hour": 16, "temperature_c": 10.1, "condition": "sunny", "solar_irradiance": 333.3, "humidity": 67.4, "wind_speed": 4.4}, {"day": 1, "hour": 17, "temperature_c": 10.4, "condition": "sunny", "solar_irradiance": 166.7, "humidity": 72.7, "wind_speed": 6.0}, {"day": 1, "hour": 18, "temperature_c": 10.9, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 77.2, "wind_speed": 5.2}, {"day": 1, "hour": 19, "temperature_c": 11.6, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 39.9, "wind_speed": 3.8}, {"day": 1, "hour": 20, "temperature_c": 11.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 69.1, "wind_speed": 5.9}, {"day": 1, "hour": 21, "temperature_c": 8.5, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 66.5, "wind_speed": 11.5}, {"day": 1, "hour": 22, "temperature_c": 8.6, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 52.6, "wind_speed": 15.5}, {"day": 1, "hour": 23, "temperature_c": 8.9, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 45.3, "wind_speed": 6.2}]}', name='get_weather_forecast', id='876e7695-8431-4c6b-b571-d11c6220bbff', tool_call_id='call_hg2SPayp0Y6eZQVgmKCw2lJI'),
#     AIMessage(content='To minimize your electricity bill while running your dishwasher and laundry tomorrow (October 7, 2023), here’s the optimal schedule based on electricity prices and solar generation:\n\n### Recommended Schedule:\n1. **Run Dishwasher:**\n   - **Time:** 10:00 AM - 12:00 PM\n   - **Electricity Rate:** $0.149 to $0.139 per kWh (mid-peak)\n   - **Reasoning:** This time has a lower mid-peak rate compared to the later afternoon peak hours.\n\n2. **Run Laundry:**\n   - **Time:** 12:00 PM - 2:00 PM\n   - **Electricity Rate:** $0.139 to $0.1328 per kWh (mid-peak)\n   - **Reasoning:** Continuing in the mid-peak period allows you to take advantage of slightly lower rates before the peak pricing starts.\n\n### Tradeoffs:\n- **Comfort:** Running both appliances during the day may require you to adjust your schedule slightly.\n- **Solar Generation:** The solar generation is expected to be higher in the afternoon (up to 833.3 W/m² at 1 PM), which can help offset costs if you have solar panels.\n\n### Estimated Savings:\n- By avoiding peak hours (3 PM - 8 PM, rates up to $0.2096), you could save approximately 20-30% on your electricity bill for these appliances compared to running them during peak hours.\n\nThis schedule balances cost savings with practical appliance use while considering solar generation potential.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 317, 'prompt_tokens': 3365, 'total_tokens': 3682, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAHufE7UlAEuNYrD8yPmFPdM7MFj3', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c5c-33ba-7312-8a80-8bb7924abda6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3365, 'output_tokens': 317, 'total_tokens': 3682, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_electricity_prices'],
#   'expected_response': 'The response should recommend specific off-peak times for both appliances',
#   'timestamp': '2026-02-17T17:08:32.752830'},
#  {'test_id': 'appliance_2',
#   'question': 'I can run my water heater for only 3 hours today. Which hours are best?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='b42ebc0e-6ed1-4a87-8b3b-eb823b817b13'),
#     HumanMessage(content='I can run my water heater for only 3 hours today. Which hours are best?', additional_kwargs={}, response_metadata={}, id='a9942bd2-e6de-43f4-9b54-7acea36095f6'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 53, 'prompt_tokens': 1050, 'total_tokens': 1103, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAHukctyuK33QtA5J9WJXvu54YQqR', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c5c-46f2-7aa2-b53c-e514bbbcf6ee-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {}, 'id': 'call_JtggIFfcPvqQzcxr6oRrfq3n', 'type': 'tool_call'}, {'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 1}, 'id': 'call_CfmdYJLt5mP6hHbup9HmcKvg', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1050, 'output_tokens': 53, 'total_tokens': 1103, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"date": "2026-02-17", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.0953, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.1063, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.1101, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.1103, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.0956, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.1022, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.1326, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 7, "rate": 0.1375, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 8, "rate": 0.1311, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 9, "rate": 0.1495, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 10, "rate": 0.1445, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 11, "rate": 0.1406, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 12, "rate": 0.1427, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 13, "rate": 0.1363, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 14, "rate": 0.1362, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 15, "rate": 0.1424, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 16, "rate": 0.2024, "period": "peak", "demand_charge": 0.04}, {"hour": 17, "rate": 0.2026, "period": "peak", "demand_charge": 0.04}, {"hour": 18, "rate": 0.1941, "period": "peak", "demand_charge": 0.04}, {"hour": 19, "rate": 0.2106, "period": "peak", "demand_charge": 0.04}, {"hour": 20, "rate": 0.2007, "period": "peak", "demand_charge": 0.04}, {"hour": 21, "rate": 0.2033, "period": "peak", "demand_charge": 0.04}, {"hour": 22, "rate": 0.1161, "period": "off_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.1128, "period": "off_peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='a4a7cea6-eb16-4f1b-818f-e26556e5be64', tool_call_id='call_JtggIFfcPvqQzcxr6oRrfq3n'),
#     ToolMessage(content='{"location": "San Francisco, CA", "forecast_days": 1, "current": {"temperature_c": 7.7, "condition": "sunny", "humidity": 62.2, "wind_speed": 17.8}, "hourly": [{"day": 1, "hour": 0, "temperature_c": 9.5, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 71.1, "wind_speed": 5.5}, {"day": 1, "hour": 1, "temperature_c": 11.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 44.5, "wind_speed": 8.8}, {"day": 1, "hour": 2, "temperature_c": 11.3, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 33.8, "wind_speed": 7.8}, {"day": 1, "hour": 3, "temperature_c": 11.6, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 39.6, "wind_speed": 4.1}, {"day": 1, "hour": 4, "temperature_c": 9.1, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 60.5, "wind_speed": 10.3}, {"day": 1, "hour": 5, "temperature_c": 11.0, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 52.2, "wind_speed": 9.2}, {"day": 1, "hour": 6, "temperature_c": 10.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 74.4, "wind_speed": 9.8}, {"day": 1, "hour": 7, "temperature_c": 10.9, "condition": "partly_cloudy", "solar_irradiance": 116.7, "humidity": 64.4, "wind_speed": 7.3}, {"day": 1, "hour": 8, "temperature_c": 10.1, "condition": "partly_cloudy", "solar_irradiance": 233.3, "humidity": 78.9, "wind_speed": 9.1}, {"day": 1, "hour": 9, "temperature_c": 12.3, "condition": "sunny", "solar_irradiance": 500.0, "humidity": 46.7, "wind_speed": 6.6}, {"day": 1, "hour": 10, "temperature_c": 13.0, "condition": "partly_cloudy", "solar_irradiance": 466.7, "humidity": 40.2, "wind_speed": 15.7}, {"day": 1, "hour": 11, "temperature_c": 16.2, "condition": "partly_cloudy", "solar_irradiance": 583.3, "humidity": 70.5, "wind_speed": 12.0}, {"day": 1, "hour": 12, "temperature_c": 17.7, "condition": "partly_cloudy", "solar_irradiance": 700.0, "humidity": 53.6, "wind_speed": 15.5}, {"day": 1, "hour": 13, "temperature_c": 14.9, "condition": "cloudy", "solar_irradiance": 291.7, "humidity": 76.8, "wind_speed": 11.4}, {"day": 1, "hour": 14, "temperature_c": 15.1, "condition": "cloudy", "solar_irradiance": 233.3, "humidity": 66.0, "wind_speed": 11.0}, {"day": 1, "hour": 15, "temperature_c": 11.6, "condition": "cloudy", "solar_irradiance": 175.0, "humidity": 64.4, "wind_speed": 4.1}, {"day": 1, "hour": 16, "temperature_c": 10.4, "condition": "partly_cloudy", "solar_irradiance": 233.3, "humidity": 50.0, "wind_speed": 19.2}, {"day": 1, "hour": 17, "temperature_c": 9.3, "condition": "partly_cloudy", "solar_irradiance": 116.7, "humidity": 42.8, "wind_speed": 19.8}, {"day": 1, "hour": 18, "temperature_c": 11.5, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 79.3, "wind_speed": 14.2}, {"day": 1, "hour": 19, "temperature_c": 9.6, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 58.5, "wind_speed": 6.8}, {"day": 1, "hour": 20, "temperature_c": 9.6, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 62.4, "wind_speed": 8.9}, {"day": 1, "hour": 21, "temperature_c": 10.0, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 71.6, "wind_speed": 9.2}, {"day": 1, "hour": 22, "temperature_c": 9.9, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 52.7, "wind_speed": 16.4}, {"day": 1, "hour": 23, "temperature_c": 9.8, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 60.3, "wind_speed": 17.6}]}', name='get_weather_forecast', id='bb6d5af5-92a0-42c5-94ba-a248a048d150', tool_call_id='call_CfmdYJLt5mP6hHbup9HmcKvg'),
# ...
#     ToolMessage(content='{"date": "2023-10-14", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.1021, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.0962, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.1118, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.1017, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.0959, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.097, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.1386, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 7, "rate": 0.1328, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 8, "rate": 0.1455, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 9, "rate": 0.1458, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 10, "rate": 0.1337, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 11, "rate": 0.1394, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 12, "rate": 0.1336, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 13, "rate": 0.1416, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 14, "rate": 0.1457, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 15, "rate": 0.1368, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 16, "rate": 0.2061, "period": "peak", "demand_charge": 0.04}, {"hour": 17, "rate": 0.1972, "period": "peak", "demand_charge": 0.04}, {"hour": 18, "rate": 0.1954, "period": "peak", "demand_charge": 0.04}, {"hour": 19, "rate": 0.1933, "period": "peak", "demand_charge": 0.04}, {"hour": 20, "rate": 0.1932, "period": "peak", "demand_charge": 0.04}, {"hour": 21, "rate": 0.1942, "period": "peak", "demand_charge": 0.04}, {"hour": 22, "rate": 0.1208, "period": "off_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.1196, "period": "off_peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='bb1819b9-2a0f-475c-8e12-4afaf53b2522', tool_call_id='call_c3WJNG18FWOZlhEVCTbV5MIy'),
#     AIMessage(content="Yes, you should delay EV charging to noon tomorrow. Here's why:\n\n### Recommendations:\n- **Charge your EV from 12 PM to 4 PM** when solar generation is at its peak (solar irradiance reaches 1000 W/m² at noon).\n  \n### Benefits:\n1. **Cost Savings**: \n   - Charging during this time will utilize solar energy, reducing reliance on grid electricity.\n   - The electricity rate from 12 PM to 4 PM is around **$0.1336 to $0.1457 per kWh**, which is lower than peak rates later in the day (up to $0.2061).\n\n2. **Environmental Impact**: \n   - Charging during sunny hours maximizes solar self-consumption, reducing your carbon footprint.\n\n### Estimated Savings:\n- If you charge your EV for 4 hours (assuming 10 kWh usage), the cost would be approximately:\n  - **12 PM - 1 PM**: $0.1336/kWh\n  - **1 PM - 2 PM**: $0.1416/kWh\n  - **2 PM - 3 PM**: $0.1457/kWh\n  - **3 PM - 4 PM**: $0.1368/kWh\n- Total cost: **$1.34** (compared to higher rates later).\n\n### Conclusion:\nCharging during this window not only saves you money but also supports sustainable energy use.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 299, 'prompt_tokens': 3373, 'total_tokens': 3672, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAHuyaO5IZZVeK3QXv8L7aMmqafYw', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c5c-7b16-7d73-813a-ec610b4afec4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3373, 'output_tokens': 299, 'total_tokens': 3672, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_weather_forecast', 'get_electricity_prices'],
#   'expected_response': 'The response should compare solar availability vs electricity rates',
#   'timestamp': '2026-02-17T17:08:51.428119'},
#  {'test_id': 'history_1',
#   'question': 'Based on my last 7 days of usage, what are 3 ways to reduce consumption?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='6325d7a1-1898-44a9-afb4-fdfa6f0117f5'),
#     HumanMessage(content='Based on my last 7 days of usage, what are 3 ways to reduce consumption?', additional_kwargs={}, response_metadata={}, id='1c60e065-3bfe-4c02-859e-190a283d7d00'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 79, 'prompt_tokens': 1051, 'total_tokens': 1130, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAHv3mSOcwa8Auktw8CSWDLORClUR', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c5c-8fe6-7fb0-9240-f1adf8f13d0d-0', tool_calls=[{'name': 'query_energy_usage', 'args': {'start_date': '2023-10-01', 'end_date': '2023-10-08'}, 'id': 'call_fYfRqrBjJdguS0cqTfXrZz8g', 'type': 'tool_call'}, {'name': 'query_solar_generation', 'args': {'start_date': '2023-10-01', 'end_date': '2023-10-08'}, 'id': 'call_0VSDfLMGRV7rfnsP00QsbnPc', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1051, 'output_tokens': 79, 'total_tokens': 1130, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"start_date": "2023-10-01", "end_date": "2023-10-08", "device_type": null, "total_records": 0, "total_consumption_kwh": 0, "total_cost_usd": 0, "records": []}', name='query_energy_usage', id='d7026efc-21f0-41c3-a5c0-a0aeecab4f10', tool_call_id='call_fYfRqrBjJdguS0cqTfXrZz8g'),
#     ToolMessage(content='{"start_date": "2023-10-01", "end_date": "2023-10-08", "total_records": 0, "total_generation_kwh": 0, "average_daily_generation": 0.0, "records": []}', name='query_solar_generation', id='e22c9b37-13ad-4072-ad81-95fdb9f35e63', tool_call_id='call_0VSDfLMGRV7rfnsP00QsbnPc'),
#     AIMessage(content='It appears that there is no recorded energy usage or solar generation data for the last 7 days. This could be due to a lack of data collection or reporting issues.\n\nHowever, here are three general strategies to reduce energy consumption in a typical household:\n\n1. **Optimize HVAC Usage**:\n   - **Schedule**: Set your thermostat to 78°F during the day and 72°F at night. \n   - **Reasoning**: This reduces heating and cooling costs while maintaining comfort.\n   - **Expected Savings**: Up to 10-15% on HVAC costs.\n\n2. **Shift Appliance Usage**:\n   - **Schedule**: Run the dishwasher and laundry machines during off-peak hours (typically after 9 PM).\n   - **Reasoning**: This takes advantage of lower electricity rates during off-peak times.\n   - **Expected Savings**: Depending on your utility rates, this could save 5-10% on your overall bill.\n\n3. **Reduce Standby Power**:\n   - **Action**: Unplug devices or use smart power strips for electronics that are not in use.\n   - **Reasoning**: Many devices consume power even when turned off (phantom load).\n   - **Expected Savings**: Can save 5-10% on your electricity bill.\n\nIf you can provide more specific data or confirm if there are any issues with the energy monitoring system, I can offer more tailored recommendations.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 293, 'prompt_tokens': 1261, 'total_tokens': 1554, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAHv6RJEvEsOIIt1zR8TcGWkZHeJe', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c5c-9ab7-7790-bace-07263c1331c8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1261, 'output_tokens': 293, 'total_tokens': 1554, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['query_energy_usage', 'search_energy_tips'],
#   'expected_response': 'The response should reference usage patterns and provide 3 actionable recommendations',
#   'timestamp': '2026-02-17T17:08:59.170877'},
#  {'test_id': 'savings_1',
#   'question': 'How much can I save if I reduce HVAC use from 18 kWh/day to 14 kWh/day?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='dbdc37c4-0780-4159-84c8-7b6460c186d9'),
#     HumanMessage(content='How much can I save if I reduce HVAC use from 18 kWh/day to 14 kWh/day?', additional_kwargs={}, response_metadata={}, id='7fcbd1ca-003b-4332-928b-81b969768e44'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 1055, 'total_tokens': 1068, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAHvBW0A6tbbcUYnZC9Jn02jytVrJ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c5c-ae28-72b1-9d26-86793146fd80-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {}, 'id': 'call_pOcNBsu61R3KjFeELqyoM91T', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1055, 'output_tokens': 13, 'total_tokens': 1068, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"date": "2026-02-17", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.1116, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.1114, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.1066, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.1141, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.0972, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.1124, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.1376, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 7, "rate": 0.1479, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 8, "rate": 0.1305, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 9, "rate": 0.138, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 10, "rate": 0.1483, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 11, "rate": 0.1325, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 12, "rate": 0.1444, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 13, "rate": 0.1431, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 14, "rate": 0.1442, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 15, "rate": 0.1413, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 16, "rate": 0.2113, "period": "peak", "demand_charge": 0.04}, {"hour": 17, "rate": 0.1961, "period": "peak", "demand_charge": 0.04}, {"hour": 18, "rate": 0.2095, "period": "peak", "demand_charge": 0.04}, {"hour": 19, "rate": 0.2105, "period": "peak", "demand_charge": 0.04}, {"hour": 20, "rate": 0.2058, "period": "peak", "demand_charge": 0.04}, {"hour": 21, "rate": 0.2046, "period": "peak", "demand_charge": 0.04}, {"hour": 22, "rate": 0.1154, "period": "off_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.1155, "period": "off_peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='6e3fc544-66d0-41b2-9134-08a20ff15150', tool_call_id='call_pOcNBsu61R3KjFeELqyoM91T'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 41, 'prompt_tokens': 1884, 'total_tokens': 1925, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAHvCAl1CZsfZifgaXFlWUHs3KkEX', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c5c-b27b-7412-906e-0e69fe488da0-0', tool_calls=[{'name': 'calculate_energy_savings', 'args': {'device_type': 'HVAC', 'current_usage_kwh': 18, 'optimized_usage_kwh': 14, 'price_per_kwh': 0.12}, 'id': 'call_gSzAuRf4QVoBXqwLEeXne13J', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1884, 'output_tokens': 41, 'total_tokens': 1925, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"device_type": "HVAC", "current_usage_kwh": 18.0, "optimized_usage_kwh": 14.0, "savings_kwh": 4.0, "savings_usd": 0.48, "savings_percentage": 22.2, "price_per_kwh": 0.12, "annual_savings_usd": 175.2}', name='calculate_energy_savings', id='b4b35437-6fb2-4c97-9d22-fb4f4a6df478', tool_call_id='call_gSzAuRf4QVoBXqwLEeXne13J'),
#     AIMessage(content='By reducing your HVAC usage from 18 kWh/day to 14 kWh/day, you can save approximately **$0.48 per day**, which translates to about **$175.20 annually**. This reduction represents a **22.2% decrease** in your HVAC energy consumption costs. \n\n**Reasoning**: Lowering your HVAC usage during peak times can significantly cut costs, especially since electricity prices can be higher during those periods.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 91, 'prompt_tokens': 2024, 'total_tokens': 2115, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1792}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAHvDStIMz7OaYguYDJP6jo1r9rDr', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c5c-b89d-72e2-a246-791d7e86d562-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2024, 'output_tokens': 91, 'total_tokens': 2115, 'input_token_details': {'audio': 0, 'cache_read': 1792}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['calculate_energy_savings'],
#   'expected_response': 'The response should include daily and annual savings estimates',
#   'timestamp': '2026-02-17T17:09:03.970144'}]

# %% [markdown]
# ## 4. Evaluate Responses

# %%
def _extract_tool_names(messages):
    tool_names = []
    for msg in messages:
        obj = msg.model_dump() if hasattr(msg, "model_dump") else {}
        name = getattr(msg, "name", None) or obj.get("name")
        if obj.get("tool_call_id") and name:
            tool_names.append(name)
    return tool_names

# %%
def evaluate_response(question, final_response, expected_response):
    """Evaluate a single response against expected response using simple heuristics."""
    text = (final_response or "").lower()
    exp = (expected_response or "").lower()

    score = 0
    notes = []

    if len(text) > 120:
        score += 1
        notes.append("Response is sufficiently detailed")
    else:
        notes.append("Response may be too brief")

    action_keywords = ["recommend", "should", "schedule", "between", "hour", "am", "pm"]
    if any(k in text for k in action_keywords):
        score += 1
        notes.append("Contains actionable guidance")
    else:
        notes.append("Missing actionable schedule guidance")

    value_keywords = ["$", "save", "cost", "kwh", "annual", "usd"]
    if any(k in text for k in value_keywords):
        score += 1
        notes.append("Includes cost/savings context")
    else:
        notes.append("Missing cost/savings context")

    if any(token in text for token in exp.replace(",", " ").split()[:8]):
        score += 1
        notes.append("Aligned with expected intent")
    else:
        notes.append("Weak alignment with expected intent")

    return {
        "score": score,
        "max_score": 4,
        "passed": score >= 3,
        "notes": notes,
    }

# %%
def evaluate_tool_usage(messages, expected_tools):
    """Evaluate if the right tools were used."""
    used_tools = _extract_tool_names(messages)
    used_set = set(used_tools)
    expected_set = set(expected_tools or [])

    matched = sorted(list(expected_set.intersection(used_set)))
    missing = sorted(list(expected_set - used_set))
    extra = sorted(list(used_set - expected_set))

    precision = len(matched) / max(1, len(used_set))
    recall = len(matched) / max(1, len(expected_set))
    f1 = (2 * precision * recall / (precision + recall)) if (precision + recall) else 0

    return {
        "used_tools": used_tools,
        "expected_tools": list(expected_set),
        "matched": matched,
        "missing": missing,
        "extra": extra,
        "precision": round(precision, 2),
        "recall": round(recall, 2),
        "f1": round(f1, 2),
        "passed": recall >= 0.7,
    }

# %%
def generate_evaluation_report():
    """Generate evaluation metrics across all test_results."""
    report_rows = []
    for result in test_results:
        if isinstance(result.get("response"), dict):
            messages = result["response"].get("messages", [])
            final_response = messages[-1].content if messages else ""
        else:
            messages = []
            final_response = str(result.get("response", ""))

        response_eval = evaluate_response(
            question=result["question"],
            final_response=final_response,
            expected_response=result["expected_response"],
        )
        tool_eval = evaluate_tool_usage(messages, result["expected_tools"])

        report_rows.append({
            "test_id": result["test_id"],
            "response_score": response_eval["score"],
            "response_max": response_eval["max_score"],
            "response_passed": response_eval["passed"],
            "tool_f1": tool_eval["f1"],
            "tool_passed": tool_eval["passed"],
            "missing_tools": tool_eval["missing"],
        })

    total = len(report_rows)
    avg_response = round(sum(r["response_score"] / r["response_max"] for r in report_rows) / max(1, total), 2)
    avg_tool_f1 = round(sum(r["tool_f1"] for r in report_rows) / max(1, total), 2)
    pass_rate = round(sum(1 for r in report_rows if r["response_passed"] and r["tool_passed"]) / max(1, total), 2)

    summary = {
        "total_tests": total,
        "avg_response_score_ratio": avg_response,
        "avg_tool_f1": avg_tool_f1,
        "overall_pass_rate": pass_rate,
        "failed_tests": [r["test_id"] for r in report_rows if not (r["response_passed"] and r["tool_passed"])],
        "details": report_rows,
    }

    return summary

# %%
# Generate and display the evaluation report
evaluation_report = generate_evaluation_report()

print("=== EVALUATION REPORT ===")
print(f"Total Tests: {evaluation_report['total_tests']}")
print(f"Average Response Score: {evaluation_report['avg_response_score_ratio']}")
print(f"Average Tool F1: {evaluation_report['avg_tool_f1']}")
print(f"Overall Pass Rate: {evaluation_report['overall_pass_rate']}")

if evaluation_report['failed_tests']:
    print(f"\nFailed Tests: {', '.join(evaluation_report['failed_tests'])}")
else:
    print("\nAll tests passed!")

print("\n=== DETAILED RESULTS ===")
for detail in evaluation_report['details']:
    status = "PASS" if detail['response_passed'] and detail['tool_passed'] else "FAIL"
    print(f"  [{status}] {detail['test_id']} - Response: {detail['response_score']}/{detail['response_max']}, Tool F1: {detail['tool_f1']}")
    if detail['missing_tools']:
        print(f"         Missing tools: {detail['missing_tools']}")
# Out:
# === EVALUATION REPORT ===
# Total Tests: 10
# Average Response Score: 0.97
# Average Tool F1: 0.79
# Overall Pass Rate: 0.7
#
# Failed Tests: ev_charging_2, thermostat_1, history_1
#
# === DETAILED RESULTS ===
#   [PASS] ev_charging_1 - Response: 4/4, Tool F1: 1.0
#   [FAIL] ev_charging_2 - Response: 4/4, Tool F1: 0.67
#          Missing tools: ['calculate_energy_savings']
#   [FAIL] thermostat_1 - Response: 4/4, Tool F1: 0.67
#          Missing tools: ['get_weather_forecast']
#   [PASS] thermostat_2 - Response: 4/4, Tool F1: 1.0
#   [PASS] appliance_1 - Response: 4/4, Tool F1: 0.67
#   [PASS] appliance_2 - Response: 4/4, Tool F1: 0.67
#   [PASS] solar_1 - Response: 4/4, Tool F1: 1.0
#   [PASS] solar_2 - Response: 4/4, Tool F1: 1.0
#   [FAIL] history_1 - Response: 4/4, Tool F1: 0.5
#          Missing tools: ['search_energy_tips']
#   [PASS] savings_1 - Response: 3/4, Tool F1: 0.67
