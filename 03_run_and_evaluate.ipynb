# %% [markdown]
# # EcoHome Energy Advisor - Agent Run & Evaluation
#
# In this notebook, you'll run the Energy Advisor agent with various real-world scenarios and see how it helps customers optimize their energy usage.
#
# ## Learning Objectives
# - Create the agent's instructions
# - Run the Energy Advisor with different types of questions
# - Evaluate response quality and accuracy
# - Measure tool usage effectiveness
# - Identify areas for improvement
# - Implement evaluation metrics
#
# ## Evaluation Criteria
# - **Accuracy**: Correct information and calculations
# - **Relevance**: Responses address the user's question
# - **Completeness**: Comprehensive answers with actionable advice
# - **Tool Usage**: Appropriate use of available tools
# - **Reasoning**: Clear explanation of recommendations

# %% [markdown]
# ## 1. Import and Initialize

# %%
from datetime import datetime
from agent import Agent

# %%
ECOHOME_SYSTEM_PROMPT = """You are EcoHome Energy Advisor, an expert assistant for smart-home energy optimization.

Your goals:
1. Reduce user electricity cost while keeping comfort and practicality.
2. Reduce carbon impact by prioritizing solar generation and lower-demand periods.
3. Provide clear, actionable recommendations with concrete times and expected tradeoffs.

Rules:
- Use tools whenever recommendations depend on weather, prices, historical usage, or savings math.
- Prefer specific schedules (hours/time windows), not vague guidance.
- If data is missing, state assumptions explicitly.
- Include brief reasoning: why this schedule is better.
- Include estimated savings when possible.
- Keep answers concise and practical.

When relevant, optimize around:
- EV charging
- Thermostat/HVAC operation
- Appliance scheduling (dishwasher, laundry, water heater)
- Solar self-consumption and grid export/import balance

If the user asks for multiple options, provide a ranked list with pros/cons."""

# %%
ecohome_agent = Agent(
    instructions=ECOHOME_SYSTEM_PROMPT,
)

# %%
response = ecohome_agent.invoke(
    question="When should I charge my electric car tomorrow to minimize cost and maximize solar power?",
    context="Location: San Francisco, CA"
)

# %%
print(response["messages"][-1].content)
# Out:
# To minimize costs and maximize solar power for charging your electric vehicle (EV) tomorrow (October 7, 2023), follow this schedule:
#
# ### Recommended Charging Time:
# - **Charge your EV from 10:00 AM to 2:00 PM.**
#
# ### Reasoning:
# 1. **Solar Generation**:
#    - Solar irradiance peaks between 10:00 AM and 2:00 PM, with the highest values around 11:00 AM (833.3 W/m²) and 12:00 PM (700.0 W/m²). This means your solar panels will generate the most energy during this window, allowing you to use more solar power for charging.
#
# 2. **Electricity Rates**:
#    - The electricity rates during this time are relatively low compared to the peak hours later in the day:
#      - 10:00 AM: $0.131/kWh
#      - 11:00 AM: $0.1462/kWh
#      - 12:00 PM: $0.1318/kWh
#    - Charging during this window avoids the higher peak rates that occur in the late afternoon and evening.
#
# ### Estimated Savings:
# - If you charge your EV for 4 hours (assuming a charging rate of 7 kW), you would consume approximately 28 kWh.
# - Charging during the recommended hours at an average rate of $0.136/kWh would cost about $3.81.
# - If you charged during peak hours (e.g., 5 PM at $0.2008/kWh), the same usage would cost about $5.62.
# - **Estimated Savings**: $1.81 by charging during the recommended time.
#
# By following this schedule, you can effectively reduce your electricity costs while maximizing the use of solar energy.

# %%
print("TOOLS:")
for msg in response["messages"]:
    obj = msg.model_dump()
    if obj.get("tool_call_id"):
        print("-", msg.name)
# Out:
# TOOLS:
# - get_weather_forecast
# - get_electricity_prices

# %% [markdown]
# ## 2. Define Test Cases

# %%
# Test cases covering EV, thermostat, appliances, solar, and savings scenarios.

# %%
test_cases = [
    {
        "id": "ev_charging_1",
        "question": "When should I charge my electric car tomorrow to minimize cost and maximize solar power?",
        "expected_tools": ["get_weather_forecast", "get_electricity_prices"],
        "expected_response": "The response should contain time recommendation, cost analysis and solar consideration",
    },
    {
        "id": "ev_charging_2",
        "question": "I need 30 kWh for my EV by 7 AM. What is the cheapest charging schedule tonight?",
        "expected_tools": ["get_electricity_prices", "calculate_energy_savings"],
        "expected_response": "The response should include overnight off-peak timing and cost estimate",
    },
    {
        "id": "thermostat_1",
        "question": "What thermostat setting should I use Wednesday afternoon if prices spike?",
        "expected_tools": ["get_electricity_prices", "get_weather_forecast"],
        "expected_response": "The response should include temperature setpoint strategy and peak pricing avoidance",
    },
    {
        "id": "thermostat_2",
        "question": "How can I pre-cool my home to reduce HVAC costs during evening peak hours?",
        "expected_tools": ["get_electricity_prices", "get_weather_forecast"],
        "expected_response": "The response should include pre-cooling window, peak-hour behavior, and comfort tradeoff",
    },
    {
        "id": "appliance_1",
        "question": "When should I run my dishwasher and laundry tomorrow for the lowest bill?",
        "expected_tools": ["get_electricity_prices"],
        "expected_response": "The response should recommend specific off-peak times for both appliances",
    },
    {
        "id": "appliance_2",
        "question": "I can run my water heater for only 3 hours today. Which hours are best?",
        "expected_tools": ["get_electricity_prices"],
        "expected_response": "The response should include a 3-hour schedule based on low prices",
    },
    {
        "id": "solar_1",
        "question": "What is the best time tomorrow to run heavy loads to use maximum solar generation?",
        "expected_tools": ["get_weather_forecast"],
        "expected_response": "The response should identify midday solar window and suitable loads",
    },
    {
        "id": "solar_2",
        "question": "Should I delay EV charging to noon tomorrow if it is sunny?",
        "expected_tools": ["get_weather_forecast", "get_electricity_prices"],
        "expected_response": "The response should compare solar availability vs electricity rates",
    },
    {
        "id": "history_1",
        "question": "Based on my last 7 days of usage, what are 3 ways to reduce consumption?",
        "expected_tools": ["query_energy_usage", "search_energy_tips"],
        "expected_response": "The response should reference usage patterns and provide 3 actionable recommendations",
    },
    {
        "id": "savings_1",
        "question": "How much can I save if I reduce HVAC use from 18 kWh/day to 14 kWh/day?",
        "expected_tools": ["calculate_energy_savings"],
        "expected_response": "The response should include daily and annual savings estimates",
    },
    {
        "id": "summary_1",
        "question": "Give me a summary of my energy usage and solar generation over the last 24 hours.",
        "expected_tools": ["get_recent_energy_summary"],
        "expected_response": "The response should include total consumption, cost, device breakdown, and solar generation",
    },
    {
        "id": "tips_1",
        "question": "What are the best energy-saving tips for running my HVAC system more efficiently?",
        "expected_tools": ["search_energy_tips"],
        "expected_response": "The response should include specific HVAC tips like filter changes, thermostat settings, and duct sealing",
    },
]

if len(test_cases) < 10:
    raise ValueError("You MUST have at least 10 test cases")

# %% [markdown]
# ## 3. Run Agent Tests

# %%
CONTEXT = "Location: San Francisco, CA"

# %%
# Run the agent tests
# For each test case, call the agent and collect the response
# Store results for evaluation

print("=== Running Agent Tests ===")
test_results = []

for i, test_case in enumerate(test_cases):
    print(f"\nTest {i+1}: {test_case['id']}")
    print(f"Question: {test_case['question']}")
    print("-" * 50)
    
    try:
        # Call the agent
        response = ecohome_agent.invoke(
            question=test_case['question'],
            context=CONTEXT
        )
        
        # Store the result
        result = {
            'test_id': test_case['id'],
            'question': test_case['question'],
            'response': response,
            'expected_tools': test_case['expected_tools'],
            'expected_response': test_case['expected_response'],
            'timestamp': datetime.now().isoformat()
        }
        test_results.append(result)
                
    except Exception as e:
        print(f"Error: {e}")
        result = {
            'test_id': test_case['id'],
            'question': test_case['question'],
            'response': f"Error: {str(e)}",
            'expected_tools': test_case['expected_tools'],
            'expected_response': test_case['expected_response'],
            'timestamp': datetime.now().isoformat(),
            'error': str(e)
        }
        test_results.append(result)

print(f"\nCompleted {len(test_results)} tests")
# Out:
# === Running Agent Tests ===
#
# Test 1: ev_charging_1
# Question: When should I charge my electric car tomorrow to minimize cost and maximize solar power?
# --------------------------------------------------
#
# Test 2: ev_charging_2
# Question: I need 30 kWh for my EV by 7 AM. What is the cheapest charging schedule tonight?
# --------------------------------------------------
#
# Test 3: thermostat_1
# Question: What thermostat setting should I use Wednesday afternoon if prices spike?
# --------------------------------------------------
#
# Test 4: thermostat_2
# Question: How can I pre-cool my home to reduce HVAC costs during evening peak hours?
# --------------------------------------------------
#
# Test 5: appliance_1
# Question: When should I run my dishwasher and laundry tomorrow for the lowest bill?
# --------------------------------------------------
#
# Test 6: appliance_2
# Question: I can run my water heater for only 3 hours today. Which hours are best?
# --------------------------------------------------
#
# Test 7: solar_1
# Question: What is the best time tomorrow to run heavy loads to use maximum solar generation?
# --------------------------------------------------
#
# Test 8: solar_2
# Question: Should I delay EV charging to noon tomorrow if it is sunny?
# --------------------------------------------------
#
# Test 9: history_1
# Question: Based on my last 7 days of usage, what are 3 ways to reduce consumption?
# --------------------------------------------------
#
# Test 10: savings_1
# Question: How much can I save if I reduce HVAC use from 18 kWh/day to 14 kWh/day?
# --------------------------------------------------
#
# Test 11: summary_1
# Question: Give me a summary of my energy usage and solar generation over the last 24 hours.
# --------------------------------------------------
#
# Test 12: tips_1
# Question: What are the best energy-saving tips for running my HVAC system more efficiently?
# --------------------------------------------------
#
# Completed 12 tests

# %%
test_results
# Out:
# [{'test_id': 'ev_charging_1',
#   'question': 'When should I charge my electric car tomorrow to minimize cost and maximize solar power?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='c32e0b44-fb3e-4566-a089-b9eaf386925a'),
#     HumanMessage(content='When should I charge my electric car tomorrow to minimize cost and maximize solar power?', additional_kwargs={}, response_metadata={}, id='f5b7dc5c-e511-4139-9783-7696dea2a4dd'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 1048, 'total_tokens': 1109, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAIePzXJwfRKEt7kEZseD60xGqOjo', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c87-78ac-7111-9204-226d5eca0f12-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 1}, 'id': 'call_kKF9rRciaPUWSAwzlphshdqN', 'type': 'tool_call'}, {'name': 'get_electricity_prices', 'args': {'date': '2023-10-07'}, 'id': 'call_LAZZ0U2ofd7w9M0q5OiP26Q8', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1048, 'output_tokens': 61, 'total_tokens': 1109, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"location": "San Francisco, CA", "forecast_days": 1, "current": {"temperature_c": 13.4, "condition": "cloudy", "humidity": 67.7, "wind_speed": 13.0}, "hourly": [{"day": 1, "hour": 0, "temperature_c": 11.6, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 69.9, "wind_speed": 7.4}, {"day": 1, "hour": 1, "temperature_c": 10.0, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 65.1, "wind_speed": 10.3}, {"day": 1, "hour": 2, "temperature_c": 9.9, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 72.8, "wind_speed": 6.4}, {"day": 1, "hour": 3, "temperature_c": 11.5, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 43.1, "wind_speed": 17.7}, {"day": 1, "hour": 4, "temperature_c": 8.5, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 77.5, "wind_speed": 11.5}, {"day": 1, "hour": 5, "temperature_c": 10.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 39.0, "wind_speed": 19.4}, {"day": 1, "hour": 6, "temperature_c": 9.8, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 51.9, "wind_speed": 11.0}, {"day": 1, "hour": 7, "temperature_c": 11.9, "condition": "sunny", "solar_irradiance": 166.7, "humidity": 74.4, "wind_speed": 19.9}, {"day": 1, "hour": 8, "temperature_c": 12.7, "condition": "sunny", "solar_irradiance": 333.3, "humidity": 75.4, "wind_speed": 11.4}, {"day": 1, "hour": 9, "temperature_c": 12.9, "condition": "cloudy", "solar_irradiance": 175.0, "humidity": 71.1, "wind_speed": 7.3}, {"day": 1, "hour": 10, "temperature_c": 14.6, "condition": "partly_cloudy", "solar_irradiance": 466.7, "humidity": 42.5, "wind_speed": 8.9}, {"day": 1, "hour": 11, "temperature_c": 14.8, "condition": "partly_cloudy", "solar_irradiance": 583.3, "humidity": 39.7, "wind_speed": 9.1}, {"day": 1, "hour": 12, "temperature_c": 17.6, "condition": "cloudy", "solar_irradiance": 350.0, "humidity": 45.0, "wind_speed": 2.9}, {"day": 1, "hour": 13, "temperature_c": 14.2, "condition": "partly_cloudy", "solar_irradiance": 583.3, "humidity": 31.5, "wind_speed": 9.0}, {"day": 1, "hour": 14, "temperature_c": 12.1, "condition": "cloudy", "solar_irradiance": 233.3, "humidity": 74.0, "wind_speed": 3.7}, {"day": 1, "hour": 15, "temperature_c": 11.0, "condition": "sunny", "solar_irradiance": 500.0, "humidity": 31.6, "wind_speed": 4.3}, {"day": 1, "hour": 16, "temperature_c": 11.3, "condition": "cloudy", "solar_irradiance": 116.7, "humidity": 40.0, "wind_speed": 4.4}, {"day": 1, "hour": 17, "temperature_c": 9.3, "condition": "sunny", "solar_irradiance": 166.7, "humidity": 68.4, "wind_speed": 3.9}, {"day": 1, "hour": 18, "temperature_c": 12.0, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 73.7, "wind_speed": 7.2}, {"day": 1, "hour": 19, "temperature_c": 8.6, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 47.0, "wind_speed": 18.7}, {"day": 1, "hour": 20, "temperature_c": 12.0, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 73.0, "wind_speed": 10.9}, {"day": 1, "hour": 21, "temperature_c": 11.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 38.4, "wind_speed": 6.0}, {"day": 1, "hour": 22, "temperature_c": 11.7, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 43.3, "wind_speed": 6.9}, {"day": 1, "hour": 23, "temperature_c": 9.9, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 50.2, "wind_speed": 5.1}]}', name='get_weather_forecast', id='1b845458-7bf8-4df3-959a-e96b1616c8fb', tool_call_id='call_kKF9rRciaPUWSAwzlphshdqN'),
#     ToolMessage(content='{"date": "2023-10-07", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.0979, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.1083, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.1033, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.1018, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.1051, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.1145, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.1349, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 7, "rate": 0.1493, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 8, "rate": 0.1446, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 9, "rate": 0.1472, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 10, "rate": 0.1489, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 11, "rate": 0.1323, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 12, "rate": 0.1338, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 13, "rate": 0.1404, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 14, "rate": 0.1321, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 15, "rate": 0.144, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 16, "rate": 0.2063, "period": "peak", "demand_charge": 0.04}, {"hour": 17, "rate": 0.1999, "period": "peak", "demand_charge": 0.04}, {"hour": 18, "rate": 0.196, "period": "peak", "demand_charge": 0.04}, {"hour": 19, "rate": 0.2111, "period": "peak", "demand_charge": 0.04}, {"hour": 20, "rate": 0.2031, "period": "peak", "demand_charge": 0.04}, {"hour": 21, "rate": 0.2097, "period": "peak", "demand_charge": 0.04}, {"hour": 22, "rate": 0.1179, "period": "off_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.1266, "period": "off_peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='b6e64b13-24be-4c05-8665-0a888106a6b8', tool_call_id='call_LAZZ0U2ofd7w9M0q5OiP26Q8'),
#     AIMessage(content='To minimize costs and maximize solar power for charging your electric vehicle (EV) tomorrow (October 7, 2023), follow this schedule:\n\n### Recommended Charging Time:\n- **Charge from 12:00 PM to 4:00 PM**\n\n### Reasoning:\n1. **Solar Generation**: \n   - Solar irradiance is highest between 12 PM and 4 PM, peaking at 583.3 W/m² around 1 PM and 2 PM. This means your solar panels will generate the most energy during this time, allowing you to use more solar power for charging.\n\n2. **Electricity Rates**:\n   - The rates during this time are mid-peak, ranging from $0.1321 to $0.1440 per kWh. While these are not the lowest rates, they are significantly lower than the peak rates from 4 PM onwards, which can go up to $0.2063.\n\n### Estimated Savings:\n- Charging during this window allows you to utilize solar energy, reducing reliance on grid electricity. If you charge your EV with solar power, you can save on the higher peak rates later in the day.\n\n### Trade-offs:\n- Charging during mid-peak hours may not be as cost-effective as off-peak hours (like late night), but the benefit of using solar energy outweighs the cost difference, especially if you have a solar system installed.\n\nBy following this schedule, you can effectively reduce your electricity costs while maximizing the use of renewable energy.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 305, 'prompt_tokens': 3372, 'total_tokens': 3677, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAIeRmPGm4rzCCZWAi6joTaxdFVdh', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c87-80db-7220-953f-f5eb3e92b338-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3372, 'output_tokens': 305, 'total_tokens': 3677, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_weather_forecast', 'get_electricity_prices'],
#   'expected_response': 'The response should contain time recommendation, cost analysis and solar consideration',
#   'timestamp': '2026-02-17T17:55:52.042240'},
#  {'test_id': 'ev_charging_2',
#   'question': 'I need 30 kWh for my EV by 7 AM. What is the cheapest charging schedule tonight?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='d0d5d3f1-30db-4470-ac0b-b6cca5e55633'),
#     HumanMessage(content='I need 30 kWh for my EV by 7 AM. What is the cheapest charging schedule tonight?', additional_kwargs={}, response_metadata={}, id='84dcd38e-a822-4c4f-b705-7dcbb6987143'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 1054, 'total_tokens': 1067, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAIeY9YBGzgHgxRRD1hXPsRAWthge', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c87-99ec-7470-9290-56983622b1fc-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {}, 'id': 'call_t3uCYn4zzwQ3KfhI0DynEsU9', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1054, 'output_tokens': 13, 'total_tokens': 1067, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"date": "2026-02-17", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.1142, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.1146, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.1009, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.1028, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.1014, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.1136, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.1452, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 7, "rate": 0.147, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 8, "rate": 0.144, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 9, "rate": 0.1444, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 10, "rate": 0.1312, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 11, "rate": 0.149, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 12, "rate": 0.1397, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 13, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 14, "rate": 0.131, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 15, "rate": 0.1376, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 16, "rate": 0.2055, "period": "peak", "demand_charge": 0.04}, {"hour": 17, "rate": 0.2026, "period": "peak", "demand_charge": 0.04}, {"hour": 18, "rate": 0.211, "period": "peak", "demand_charge": 0.04}, {"hour": 19, "rate": 0.195, "period": "peak", "demand_charge": 0.04}, {"hour": 20, "rate": 0.2094, "period": "peak", "demand_charge": 0.04}, {"hour": 21, "rate": 0.2069, "period": "peak", "demand_charge": 0.04}, {"hour": 22, "rate": 0.1252, "period": "off_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.1204, "period": "off_peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='ada2d7b1-c5f3-4ff3-a7a8-28cad7e7a806', tool_call_id='call_t3uCYn4zzwQ3KfhI0DynEsU9'),
#     AIMessage(content='To charge your EV with 30 kWh by 7 AM, the optimal charging schedule tonight is as follows:\n\n### Recommended Charging Schedule:\n- **11 PM - 12 AM**: Charge 10 kWh at **$0.1204/kWh** (off-peak)\n- **12 AM - 1 AM**: Charge 10 kWh at **$0.1009/kWh** (off-peak)\n- **1 AM - 2 AM**: Charge 10 kWh at **$0.1146/kWh** (off-peak)\n\n### Total Cost Calculation:\n- **11 PM - 12 AM**: 10 kWh * $0.1204 = **$1.204**\n- **12 AM - 1 AM**: 10 kWh * $0.1009 = **$1.009**\n- **1 AM - 2 AM**: 10 kWh * $0.1146 = **$1.146**\n\n### Total Cost: \n**$1.204 + $1.009 + $1.146 = $3.359**\n\n### Reasoning:\nCharging during off-peak hours (11 PM - 6 AM) is significantly cheaper than during peak hours. This schedule allows you to take advantage of the lowest rates available, ensuring you meet your 30 kWh requirement by 7 AM while minimizing costs. \n\n### Estimated Savings:\nBy charging during these off-peak hours, you save compared to charging during peak hours, where rates can exceed $0.20/kWh.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 321, 'prompt_tokens': 1877, 'total_tokens': 2198, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAIeZ7cbd6LROJeA9sjKCyUFzTEt4', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c87-9f03-7ca0-ac27-9bd5ddd18886-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1877, 'output_tokens': 321, 'total_tokens': 2198, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_electricity_prices', 'calculate_energy_savings'],
#   'expected_response': 'The response should include overnight off-peak timing and cost estimate',
#   'timestamp': '2026-02-17T17:56:01.637711'},
#  {'test_id': 'thermostat_1',
#   'question': 'What thermostat setting should I use Wednesday afternoon if prices spike?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='cdf64eaa-b485-44e4-b3cc-cf7466d70986'),
#     HumanMessage(content='What thermostat setting should I use Wednesday afternoon if prices spike?', additional_kwargs={}, response_metadata={}, id='57ed8114-7791-4a11-a629-1400a64879ac'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 1044, 'total_tokens': 1066, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAIehoEzSQrdp82vDww0oz90Tb4Ko', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c87-bf66-76e3-b1a1-0b57c945aebe-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {'date': '2023-11-01'}, 'id': 'call_9KpeGApgFv8gpIHFYIQaWirP', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1044, 'output_tokens': 22, 'total_tokens': 1066, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"date": "2023-11-01", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.1012, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.1107, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.1076, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.1103, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.1066, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.0988, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.1304, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 7, "rate": 0.1386, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 8, "rate": 0.1351, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 9, "rate": 0.1401, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 10, "rate": 0.1447, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 11, "rate": 0.1412, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 12, "rate": 0.1446, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 13, "rate": 0.1337, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 14, "rate": 0.1348, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 15, "rate": 0.1306, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 16, "rate": 0.1941, "period": "peak", "demand_charge": 0.04}, {"hour": 17, "rate": 0.2066, "period": "peak", "demand_charge": 0.04}, {"hour": 18, "rate": 0.2062, "period": "peak", "demand_charge": 0.04}, {"hour": 19, "rate": 0.2075, "period": "peak", "demand_charge": 0.04}, {"hour": 20, "rate": 0.1933, "period": "peak", "demand_charge": 0.04}, {"hour": 21, "rate": 0.203, "period": "peak", "demand_charge": 0.04}, {"hour": 22, "rate": 0.1288, "period": "off_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.1268, "period": "off_peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='9d4ad549-104d-4dcd-a981-aed1717755ef', tool_call_id='call_9KpeGApgFv8gpIHFYIQaWirP'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1882, 'total_tokens': 1905, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAIeiAWuteLBZW4yH3A8gEc70RCbq', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c87-c460-7d11-88d7-49b565729b30-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 1}, 'id': 'call_lpDKMKqWGSIRbuAa0IsMvshP', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1882, 'output_tokens': 23, 'total_tokens': 1905, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"location": "San Francisco, CA", "forecast_days": 1, "current": {"temperature_c": 12.3, "condition": "sunny", "humidity": 66.6, "wind_speed": 5.5}, "hourly": [{"day": 1, "hour": 0, "temperature_c": 10.0, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 49.7, "wind_speed": 5.2}, {"day": 1, "hour": 1, "temperature_c": 11.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 59.7, "wind_speed": 6.6}, {"day": 1, "hour": 2, "temperature_c": 11.2, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 37.4, "wind_speed": 18.7}, {"day": 1, "hour": 3, "temperature_c": 8.9, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 31.3, "wind_speed": 18.2}, {"day": 1, "hour": 4, "temperature_c": 9.1, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 62.2, "wind_speed": 17.5}, {"day": 1, "hour": 5, "temperature_c": 8.6, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 30.2, "wind_speed": 14.1}, {"day": 1, "hour": 6, "temperature_c": 10.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 34.0, "wind_speed": 7.7}, {"day": 1, "hour": 7, "temperature_c": 12.0, "condition": "partly_cloudy", "solar_irradiance": 116.7, "humidity": 34.8, "wind_speed": 4.5}, {"day": 1, "hour": 8, "temperature_c": 13.1, "condition": "sunny", "solar_irradiance": 333.3, "humidity": 55.7, "wind_speed": 2.2}, {"day": 1, "hour": 9, "temperature_c": 12.7, "condition": "sunny", "solar_irradiance": 500.0, "humidity": 73.5, "wind_speed": 7.7}, {"day": 1, "hour": 10, "temperature_c": 15.4, "condition": "sunny", "solar_irradiance": 666.7, "humidity": 57.5, "wind_speed": 2.8}, {"day": 1, "hour": 11, "temperature_c": 14.2, "condition": "partly_cloudy", "solar_irradiance": 583.3, "humidity": 76.7, "wind_speed": 2.9}, {"day": 1, "hour": 12, "temperature_c": 17.8, "condition": "cloudy", "solar_irradiance": 350.0, "humidity": 74.2, "wind_speed": 7.8}, {"day": 1, "hour": 13, "temperature_c": 15.2, "condition": "sunny", "solar_irradiance": 833.3, "humidity": 54.7, "wind_speed": 14.0}, {"day": 1, "hour": 14, "temperature_c": 13.8, "condition": "sunny", "solar_irradiance": 666.7, "humidity": 74.7, "wind_speed": 9.1}, {"day": 1, "hour": 15, "temperature_c": 13.3, "condition": "sunny", "solar_irradiance": 500.0, "humidity": 31.6, "wind_speed": 10.9}, {"day": 1, "hour": 16, "temperature_c": 11.6, "condition": "cloudy", "solar_irradiance": 116.7, "humidity": 72.4, "wind_speed": 16.0}, {"day": 1, "hour": 17, "temperature_c": 10.5, "condition": "sunny", "solar_irradiance": 166.7, "humidity": 60.6, "wind_speed": 12.8}, {"day": 1, "hour": 18, "temperature_c": 11.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 50.0, "wind_speed": 14.3}, {"day": 1, "hour": 19, "temperature_c": 10.1, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 34.7, "wind_speed": 12.9}, {"day": 1, "hour": 20, "temperature_c": 11.3, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 78.7, "wind_speed": 8.1}, {"day": 1, "hour": 21, "temperature_c": 11.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 64.0, "wind_speed": 19.7}, {"day": 1, "hour": 22, "temperature_c": 11.0, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 55.1, "wind_speed": 3.3}, {"day": 1, "hour": 23, "temperature_c": 10.1, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 49.5, "wind_speed": 7.1}]}', name='get_weather_forecast', id='97a460db-41a8-4a14-aa92-a81f3bac4d4c', tool_call_id='call_lpDKMKqWGSIRbuAa0IsMvshP'),
#     AIMessage(content='On Wednesday, November 1st, electricity prices will spike during the peak hours of 4 PM to 7 PM, with rates reaching up to $0.2066 per kWh. To optimize your thermostat setting during this time, consider the following recommendations:\n\n### Recommended Thermostat Setting:\n- **Set your thermostat to 78°F (26°C)** from **4 PM to 7 PM**.\n\n### Reasoning:\n1. **Cost Savings**: By raising the temperature to 78°F, you reduce the demand on your HVAC system during peak pricing hours, which can help avoid high electricity costs.\n2. **Comfort**: This temperature is generally considered comfortable for most people, especially if you can use fans or natural ventilation to assist.\n3. **Energy Efficiency**: Keeping the thermostat higher during peak hours can significantly lower your energy consumption, especially when combined with solar generation earlier in the day.\n\n### Expected Tradeoffs:\n- **Slightly warmer indoor temperature**: You may feel a bit warmer than usual, but this is a common practice during peak pricing to save on costs.\n- **Potential discomfort**: If you are sensitive to heat, consider using fans or adjusting the setting slightly lower if needed.\n\nBy implementing this strategy, you can effectively manage your energy costs while maintaining comfort in your home.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 266, 'prompt_tokens': 3360, 'total_tokens': 3626, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1792}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAIek5UQAFmA72dLK2DBZ9lyM8epb', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c87-c927-70d3-90f7-c18a084126a1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3360, 'output_tokens': 266, 'total_tokens': 3626, 'input_token_details': {'audio': 0, 'cache_read': 1792}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_electricity_prices', 'get_weather_forecast'],
#   'expected_response': 'The response should include temperature setpoint strategy and peak pricing avoidance',
#   'timestamp': '2026-02-17T17:56:11.365694'},
#  {'test_id': 'thermostat_2',
#   'question': 'How can I pre-cool my home to reduce HVAC costs during evening peak hours?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='0b6bc093-2f0a-483c-bafb-a9e46e56d0f0'),
#     HumanMessage(content='How can I pre-cool my home to reduce HVAC costs during evening peak hours?', additional_kwargs={}, response_metadata={}, id='067cb441-3dcf-4e3b-aa2c-a7db1d1af3b3'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 1049, 'total_tokens': 1103, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAIerqvSPsv7NPjsgdPM9QP262HTP', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c87-e567-7163-ab78-e25d2929b92c-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 1}, 'id': 'call_NE4gLNCC9QQX6XdZlk4lGU0G', 'type': 'tool_call'}, {'name': 'get_electricity_prices', 'args': {}, 'id': 'call_TBQiAzRtApQpqggeObp8lfM7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1049, 'output_tokens': 54, 'total_tokens': 1103, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"location": "San Francisco, CA", "forecast_days": 1, "current": {"temperature_c": 8.0, "condition": "sunny", "humidity": 57.3, "wind_speed": 4.1}, "hourly": [{"day": 1, "hour": 0, "temperature_c": 9.8, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 30.5, "wind_speed": 5.0}, {"day": 1, "hour": 1, "temperature_c": 9.6, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 45.0, "wind_speed": 4.9}, {"day": 1, "hour": 2, "temperature_c": 10.0, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 76.4, "wind_speed": 14.7}, {"day": 1, "hour": 3, "temperature_c": 11.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 54.0, "wind_speed": 19.3}, {"day": 1, "hour": 4, "temperature_c": 11.5, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 63.3, "wind_speed": 6.3}, {"day": 1, "hour": 5, "temperature_c": 10.9, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 73.4, "wind_speed": 12.1}, {"day": 1, "hour": 6, "temperature_c": 11.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 52.9, "wind_speed": 13.7}, {"day": 1, "hour": 7, "temperature_c": 11.7, "condition": "partly_cloudy", "solar_irradiance": 116.7, "humidity": 65.0, "wind_speed": 10.8}, {"day": 1, "hour": 8, "temperature_c": 10.5, "condition": "cloudy", "solar_irradiance": 116.7, "humidity": 38.9, "wind_speed": 9.1}, {"day": 1, "hour": 9, "temperature_c": 14.0, "condition": "partly_cloudy", "solar_irradiance": 350.0, "humidity": 79.1, "wind_speed": 9.6}, {"day": 1, "hour": 10, "temperature_c": 13.2, "condition": "cloudy", "solar_irradiance": 233.3, "humidity": 56.2, "wind_speed": 4.9}, {"day": 1, "hour": 11, "temperature_c": 17.0, "condition": "partly_cloudy", "solar_irradiance": 583.3, "humidity": 74.2, "wind_speed": 5.0}, {"day": 1, "hour": 12, "temperature_c": 16.8, "condition": "sunny", "solar_irradiance": 1000.0, "humidity": 32.8, "wind_speed": 2.9}, {"day": 1, "hour": 13, "temperature_c": 15.1, "condition": "partly_cloudy", "solar_irradiance": 583.3, "humidity": 75.1, "wind_speed": 7.9}, {"day": 1, "hour": 14, "temperature_c": 15.2, "condition": "partly_cloudy", "solar_irradiance": 466.7, "humidity": 70.4, "wind_speed": 5.1}, {"day": 1, "hour": 15, "temperature_c": 13.5, "condition": "sunny", "solar_irradiance": 500.0, "humidity": 74.7, "wind_speed": 6.7}, {"day": 1, "hour": 16, "temperature_c": 10.3, "condition": "cloudy", "solar_irradiance": 116.7, "humidity": 41.9, "wind_speed": 12.8}, {"day": 1, "hour": 17, "temperature_c": 12.1, "condition": "sunny", "solar_irradiance": 166.7, "humidity": 60.6, "wind_speed": 5.2}, {"day": 1, "hour": 18, "temperature_c": 9.9, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 77.5, "wind_speed": 19.7}, {"day": 1, "hour": 19, "temperature_c": 11.5, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 39.1, "wind_speed": 6.8}, {"day": 1, "hour": 20, "temperature_c": 8.3, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 34.2, "wind_speed": 6.6}, {"day": 1, "hour": 21, "temperature_c": 9.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 60.8, "wind_speed": 18.5}, {"day": 1, "hour": 22, "temperature_c": 9.9, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 70.2, "wind_speed": 18.6}, {"day": 1, "hour": 23, "temperature_c": 10.6, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 41.5, "wind_speed": 19.0}]}', name='get_weather_forecast', id='9fe2188d-d6ac-4417-9866-9ed4af8c3e0c', tool_call_id='call_NE4gLNCC9QQX6XdZlk4lGU0G'),
#     ToolMessage(content='{"date": "2026-02-17", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.1094, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.1011, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.115, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.0996, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.1071, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.1047, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.1312, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 7, "rate": 0.131, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 8, "rate": 0.1375, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 9, "rate": 0.1362, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 10, "rate": 0.1428, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 11, "rate": 0.145, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 12, "rate": 0.1389, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 13, "rate": 0.1333, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 14, "rate": 0.1428, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 15, "rate": 0.1391, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 16, "rate": 0.2065, "period": "peak", "demand_charge": 0.04}, {"hour": 17, "rate": 0.2121, "period": "peak", "demand_charge": 0.04}, {"hour": 18, "rate": 0.2077, "period": "peak", "demand_charge": 0.04}, {"hour": 19, "rate": 0.2064, "period": "peak", "demand_charge": 0.04}, {"hour": 20, "rate": 0.1993, "period": "peak", "demand_charge": 0.04}, {"hour": 21, "rate": 0.2065, "period": "peak", "demand_charge": 0.04}, {"hour": 22, "rate": 0.1106, "period": "off_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.1142, "period": "off_peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='73ce6424-5ffa-47c7-977c-de9dc24c4b48', tool_call_id='call_TBQiAzRtApQpqggeObp8lfM7'),
#     AIMessage(content='To pre-cool your home and reduce HVAC costs during evening peak hours, follow this schedule:\n\n### Recommended Schedule:\n- **Pre-Cool Period**: 2 PM - 5 PM\n  - **Set Thermostat to Lower Temperature**: Aim for 72°F (22°C) during this time.\n- **Peak Hours**: 5 PM - 9 PM\n  - **Set Thermostat to Higher Temperature**: Increase to 78°F (26°C) during peak hours.\n\n### Reasoning:\n1. **Electricity Rates**: \n   - Peak rates (5 PM - 9 PM) are significantly higher (up to $0.2121 per kWh).\n   - Off-peak rates (2 PM - 5 PM) are lower (around $0.1047 to $0.1312 per kWh).\n2. **Temperature Management**: Pre-cooling during the afternoon allows your home to remain comfortable without running the AC during the more expensive peak hours.\n\n### Expected Tradeoffs:\n- **Comfort**: You may feel warmer during peak hours, but the pre-cooling will help maintain comfort.\n- **Energy Usage**: You will use more energy during the pre-cool period, but it will be at a lower rate.\n\n### Estimated Savings:\nAssuming your HVAC system uses about 3 kWh per hour:\n- **Pre-Cool (3 hours)**: 3 kWh * $0.1312 = $0.39\n- **Peak (4 hours)**: 3 kWh * $0.2121 = $2.54\n- **Savings**: By shifting usage, you save approximately $2.15 during peak hours compared to running the AC continuously.\n\nImplementing this strategy can lead to significant savings on your electricity bill while maintaining comfort in your home.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 374, 'prompt_tokens': 3362, 'total_tokens': 3736, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAIetBa1WkZOCsUvnpPwcA2C45MAo', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c87-ed5e-7863-ae91-150e78ae7067-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3362, 'output_tokens': 374, 'total_tokens': 3736, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_electricity_prices', 'get_weather_forecast'],
#   'expected_response': 'The response should include pre-cooling window, peak-hour behavior, and comfort tradeoff',
#   'timestamp': '2026-02-17T17:56:21.306180'},
#  {'test_id': 'appliance_1',
#   'question': 'When should I run my dishwasher and laundry tomorrow for the lowest bill?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='c47fd7dc-0f57-4af5-93a6-31e0f8d5029b'),
#     HumanMessage(content='When should I run my dishwasher and laundry tomorrow for the lowest bill?', additional_kwargs={}, response_metadata={}, id='38707579-bfbc-4ffe-8ce5-d1ae785fadc3'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 1046, 'total_tokens': 1107, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAIf2vTuWkjytZ5COo5tR1WYcpqYn', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c88-0c3b-7642-b9ce-293d231af6bd-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {'date': '2023-10-07'}, 'id': 'call_GpJNkzPEMNGuOLm0zmwRZZi2', 'type': 'tool_call'}, {'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 1}, 'id': 'call_NVP8lJ0ovJ4p9kaFjYo4dEVO', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1046, 'output_tokens': 61, 'total_tokens': 1107, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"date": "2023-10-07", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.1045, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.1048, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.108, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.0977, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.1087, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.1138, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.1427, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 7, "rate": 0.1462, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 8, "rate": 0.1321, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 9, "rate": 0.1356, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 10, "rate": 0.1478, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 11, "rate": 0.1467, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 12, "rate": 0.142, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 13, "rate": 0.1492, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 14, "rate": 0.1387, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 15, "rate": 0.1478, "period": "mid_peak", "demand_charge": 0.01}, {"hour": 16, "rate": 0.2067, "period": "peak", "demand_charge": 0.04}, {"hour": 17, "rate": 0.2015, "period": "peak", "demand_charge": 0.04}, {"hour": 18, "rate": 0.205, "period": "peak", "demand_charge": 0.04}, {"hour": 19, "rate": 0.1987, "period": "peak", "demand_charge": 0.04}, {"hour": 20, "rate": 0.2012, "period": "peak", "demand_charge": 0.04}, {"hour": 21, "rate": 0.2029, "period": "peak", "demand_charge": 0.04}, {"hour": 22, "rate": 0.1188, "period": "off_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.1266, "period": "off_peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='f4fd4c5c-bf27-4329-9bbc-498f2c97c541', tool_call_id='call_GpJNkzPEMNGuOLm0zmwRZZi2'),
#     ToolMessage(content='{"location": "San Francisco, CA", "forecast_days": 1, "current": {"temperature_c": 9.5, "condition": "sunny", "humidity": 37.4, "wind_speed": 11.4}, "hourly": [{"day": 1, "hour": 0, "temperature_c": 10.0, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 79.5, "wind_speed": 8.8}, {"day": 1, "hour": 1, "temperature_c": 11.0, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 50.1, "wind_speed": 11.9}, {"day": 1, "hour": 2, "temperature_c": 11.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 41.4, "wind_speed": 18.2}, {"day": 1, "hour": 3, "temperature_c": 11.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 58.0, "wind_speed": 6.8}, {"day": 1, "hour": 4, "temperature_c": 8.5, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 41.1, "wind_speed": 15.1}, {"day": 1, "hour": 5, "temperature_c": 9.9, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 58.8, "wind_speed": 11.7}, {"day": 1, "hour": 6, "temperature_c": 9.5, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 70.4, "wind_speed": 19.5}, {"day": 1, "hour": 7, "temperature_c": 9.2, "condition": "partly_cloudy", "solar_irradiance": 116.7, "humidity": 51.2, "wind_speed": 18.0}, {"day": 1, "hour": 8, "temperature_c": 13.2, "condition": "partly_cloudy", "solar_irradiance": 233.3, "humidity": 50.0, "wind_speed": 10.1}, {"day": 1, "hour": 9, "temperature_c": 13.7, "condition": "cloudy", "solar_irradiance": 175.0, "humidity": 42.6, "wind_speed": 10.3}, {"day": 1, "hour": 10, "temperature_c": 13.6, "condition": "sunny", "solar_irradiance": 666.7, "humidity": 52.8, "wind_speed": 16.9}, {"day": 1, "hour": 11, "temperature_c": 16.8, "condition": "partly_cloudy", "solar_irradiance": 583.3, "humidity": 66.4, "wind_speed": 7.5}, {"day": 1, "hour": 12, "temperature_c": 15.7, "condition": "cloudy", "solar_irradiance": 350.0, "humidity": 78.1, "wind_speed": 3.5}, {"day": 1, "hour": 13, "temperature_c": 14.8, "condition": "partly_cloudy", "solar_irradiance": 583.3, "humidity": 78.2, "wind_speed": 8.3}, {"day": 1, "hour": 14, "temperature_c": 15.8, "condition": "partly_cloudy", "solar_irradiance": 466.7, "humidity": 75.6, "wind_speed": 11.9}, {"day": 1, "hour": 15, "temperature_c": 11.7, "condition": "sunny", "solar_irradiance": 500.0, "humidity": 49.5, "wind_speed": 5.0}, {"day": 1, "hour": 16, "temperature_c": 12.8, "condition": "partly_cloudy", "solar_irradiance": 233.3, "humidity": 46.9, "wind_speed": 3.4}, {"day": 1, "hour": 17, "temperature_c": 11.3, "condition": "partly_cloudy", "solar_irradiance": 116.7, "humidity": 74.8, "wind_speed": 15.3}, {"day": 1, "hour": 18, "temperature_c": 11.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 51.5, "wind_speed": 8.9}, {"day": 1, "hour": 19, "temperature_c": 9.7, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 78.1, "wind_speed": 13.2}, {"day": 1, "hour": 20, "temperature_c": 10.7, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 48.1, "wind_speed": 3.3}, {"day": 1, "hour": 21, "temperature_c": 11.2, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 35.6, "wind_speed": 5.0}, {"day": 1, "hour": 22, "temperature_c": 8.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 74.4, "wind_speed": 8.6}, {"day": 1, "hour": 23, "temperature_c": 8.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 52.8, "wind_speed": 6.4}]}', name='get_weather_forecast', id='65a6c830-6765-4191-8424-74351f10ac49', tool_call_id='call_NVP8lJ0ovJ4p9kaFjYo4dEVO'),
#     AIMessage(content='To minimize your electricity bill while running your dishwasher and laundry tomorrow (October 7, 2023), here are the optimal times based on electricity pricing:\n\n### Recommended Schedule:\n1. **Dishwasher**: Run it between **12:00 AM - 6:00 AM** (off-peak hours)\n   - **Cost**: Rates range from **$0.0977 to $0.1138 per kWh**.\n   - **Reasoning**: This is the lowest cost period of the day.\n\n2. **Laundry**: Run it between **10:00 PM - 12:00 AM** (off-peak hours)\n   - **Cost**: Rates are **$0.1045 to $0.1048 per kWh**.\n   - **Reasoning**: This period is still in the off-peak range, ensuring lower costs.\n\n### Summary of Costs:\n- **Dishwasher (6 hours)**: Average rate of about **$0.105**.\n- **Laundry (2 hours)**: Average rate of about **$0.104**.\n\n### Estimated Savings:\nBy running both appliances during these times, you can save approximately **20-30%** compared to running them during peak hours (which can exceed **$0.20 per kWh**).\n\n### Trade-offs:\n- Running appliances overnight may require you to manage noise levels if they are audible.\n- Ensure that both appliances are fully loaded to maximize efficiency.\n\nThis schedule optimizes for cost while maintaining comfort and practicality.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 312, 'prompt_tokens': 3371, 'total_tokens': 3683, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAIf5fEPsx7Regs39eTZ4qmFDNq8r', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c88-1a74-7423-b500-798983bc9bf3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3371, 'output_tokens': 312, 'total_tokens': 3683, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_electricity_prices'],
#   'expected_response': 'The response should recommend specific off-peak times for both appliances',
#   'timestamp': '2026-02-17T17:56:36.298400'},
#  {'test_id': 'appliance_2',
#   'question': 'I can run my water heater for only 3 hours today. Which hours are best?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='20e2a9d4-4990-4e43-9d75-190c359be8f6'),
#     HumanMessage(content='I can run my water heater for only 3 hours today. Which hours are best?', additional_kwargs={}, response_metadata={}, id='31c14454-fd2e-4185-8789-bdec5b1c9e4f'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 1050, 'total_tokens': 1111, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAIfGpK7bybd18zUk1b0m8JIsIDOg', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c88-46cb-7fd3-baaa-568c63bdb1ea-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {'date': '2023-10-05'}, 'id': 'call_sf56ilAyMZe67FLhZVnx88AS', 'type': 'tool_call'}, {'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 1}, 'id': 'call_b8sAVp3dww4IgPyJedUmwRlw', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1050, 'output_tokens': 61, 'total_tokens': 1111, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
# ...
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 42, 'prompt_tokens': 1883, 'total_tokens': 1925, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAIfnhqVBLe7qAfoyKNJFJCPsPvo7', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c88-c6fc-74a2-b823-3073da8fe4c6-0', tool_calls=[{'name': 'calculate_energy_savings', 'args': {'device_type': 'HVAC', 'current_usage_kwh': 18, 'optimized_usage_kwh': 14, 'price_per_kwh': 0.1339}, 'id': 'call_YU4f3oJxcsYGx2usk4YvRVKy', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1883, 'output_tokens': 42, 'total_tokens': 1925, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"device_type": "HVAC", "current_usage_kwh": 18.0, "optimized_usage_kwh": 14.0, "savings_kwh": 4.0, "savings_usd": 0.54, "savings_percentage": 22.2, "price_per_kwh": 0.1339, "annual_savings_usd": 195.49}', name='calculate_energy_savings', id='10f02c63-3f9f-4ad7-bc99-b4ef4b780501', tool_call_id='call_YU4f3oJxcsYGx2usk4YvRVKy'),
#     AIMessage(content='By reducing your HVAC usage from 18 kWh/day to 14 kWh/day, you can save approximately **$0.54 per day**, which translates to about **$195.49 annually**. This reduction represents a **22.2% savings** on your HVAC electricity costs.\n\n### Reasoning:\n- The average price per kWh is approximately **$0.1339**.\n- Reducing usage by **4 kWh/day** directly lowers your electricity bill.\n\nThis change not only saves you money but also contributes to lower energy consumption, which is beneficial for the environment.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 120, 'prompt_tokens': 2025, 'total_tokens': 2145, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1792}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAIfocsVxlcWy1KmjrvcBzGBP6XmI', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c88-cdab-7e52-8566-54a7c4e28fba-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2025, 'output_tokens': 120, 'total_tokens': 2145, 'input_token_details': {'audio': 0, 'cache_read': 1792}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['calculate_energy_savings'],
#   'expected_response': 'The response should include daily and annual savings estimates',
#   'timestamp': '2026-02-17T17:57:13.793720'},
#  {'test_id': 'summary_1',
#   'question': 'Give me a summary of my energy usage and solar generation over the last 24 hours.',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='81908e70-15f5-47c2-b4a5-3bbd3d726523'),
#     HumanMessage(content='Give me a summary of my energy usage and solar generation over the last 24 hours.', additional_kwargs={}, response_metadata={}, id='e1ac5a28-e220-4e60-8f39-f05537130fee'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 1050, 'total_tokens': 1066, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAIfrPouWnKvcyglh090acPpLy2xg', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c88-d944-71b3-8671-12f607ec67df-0', tool_calls=[{'name': 'get_recent_energy_summary', 'args': {'hours': 24}, 'id': 'call_cqKf58haG3pZgZryGdcqr0Ef', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1050, 'output_tokens': 16, 'total_tokens': 1066, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"time_period_hours": 24, "usage": {"total_consumption_kwh": 81.85, "total_cost_usd": 10.92, "device_breakdown": {"EV": {"consumption_kwh": 60.69, "cost_usd": 8.38, "records": 6}, "HVAC": {"consumption_kwh": 10.07, "cost_usd": 1.01, "records": 6}, "appliance": {"consumption_kwh": 11.1, "cost_usd": 1.53, "records": 6}}}, "generation": {"total_generation_kwh": 0.0, "average_weather": "sunny"}}', name='get_recent_energy_summary', id='fe8528dc-1bd4-4edf-a33b-3a3a061ac78c', tool_call_id='call_cqKf58haG3pZgZryGdcqr0Ef'),
#     AIMessage(content="In the last 24 hours, your energy usage and solar generation are as follows:\n\n### Energy Usage:\n- **Total Consumption:** 81.85 kWh\n- **Total Cost:** $10.92\n- **Device Breakdown:**\n  - **EV Charging:** 60.69 kWh ($8.38)\n  - **HVAC:** 10.07 kWh ($1.01)\n  - **Appliances:** 11.1 kWh ($1.53)\n\n### Solar Generation:\n- **Total Generation:** 0.0 kWh\n- **Average Weather:** Sunny\n\n### Summary:\n- You consumed a significant amount of energy primarily from EV charging, but there was no solar generation in the last 24 hours, despite sunny weather. This indicates a potential opportunity to optimize your solar usage or check your solar system's performance.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 175, 'prompt_tokens': 1234, 'total_tokens': 1409, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAIft5ZNwcxEPBbYwXkkTP0bA1pXx', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c88-dfa7-7050-8a66-7bccd4f9ee36-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1234, 'output_tokens': 175, 'total_tokens': 1409, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_recent_energy_summary'],
#   'expected_response': 'The response should include total consumption, cost, device breakdown, and solar generation',
#   'timestamp': '2026-02-17T17:57:22.403696'},
#  {'test_id': 'tips_1',
#   'question': 'What are the best energy-saving tips for running my HVAC system more efficiently?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='1064b077-cbf6-40be-a582-2bd59a8cade4'),
#     HumanMessage(content='What are the best energy-saving tips for running my HVAC system more efficiently?', additional_kwargs={}, response_metadata={}, id='282e8719-5a3a-482e-bed3-b604dbc917d3'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1047, 'total_tokens': 1070, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAIg0260uOly0xUZ4twCepCa2Hx0n', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c88-fae8-72a2-a8d9-3a54c68fc8f1-0', tool_calls=[{'name': 'search_energy_tips', 'args': {'query': 'HVAC efficiency', 'max_results': 5}, 'id': 'call_hPTSEzu9NALMwMRDbJlu6Bj5', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1047, 'output_tokens': 23, 'total_tokens': 1070, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"query": "HVAC efficiency", "total_results": 4, "tips": [{"rank": 1, "content": "Saving energy at home can be simple and effective. Turn off lights when not in use and unplug devices that draw standby power. Use natural lighting during the day and replace incandescent bulbs with energy-efficient LEDs. Keep appliances clean and well-maintained to ensure they operate efficiently.\\n\\nSmart thermostats can save up to 10% on heating and cooling costs by automatically adjusting temperatures when you\'re away. Set your thermostat to 68Â°F in winter and 78Â°F in summer for optimal energy savings.\\n\\nWash clothes in cold water and only run full loads. Use the dryer\'s moisture sensor instead of timed drying. Clean the lint filter after every load to improve efficiency.\\n\\nSeal air leaks around windows and doors with weatherstripping or caulk. Add insulation to attics and walls to reduce heating and cooling needs.\\n\\nUse power strips to easily turn off multiple devices at once. Many electronics continue to draw power even when turned off, known as phantom load.", "source": "data/documents/tip_energy_savings.txt", "relevance_score": "high"}, {"rank": 2, "content": "Dishwasher Best Practices:\\n- Only run when completely full\\n- Use the energy-saving or eco mode when available\\n- Schedule during off-peak hours or high solar generation periods\\n- Skip the heated dry cycle and air dry instead\\n\\nWater Heater Management:\\n- Set temperature to 120Â°F for optimal efficiency\\n- Insulate hot water pipes to reduce heat loss\\n- Consider a timer to turn off during peak hours\\n- Drain sediment annually to maintain efficiency\\n\\nHVAC System Optimization:\\n- Change air filters monthly for better airflow\\n- Clean outdoor condenser coils annually\\n- Use programmable thermostats to adjust temperatures automatically\\n- Seal ductwork to prevent air leaks\\n\\nPool and Spa Equipment:\\n- Run pool pumps during off-peak hours\\n- Use pool covers to reduce heating needs\\n- Consider variable-speed pumps for better efficiency\\n- Maintain proper chemical balance to reduce filtration needs", "source": "data/documents/tip_device_best_practices.txt", "relevance_score": "high"}, {"rank": 3, "content": "Use power strips to easily turn off multiple devices at once. Many electronics continue to draw power even when turned off, known as phantom load.\\n\\nConsider energy-efficient appliances when replacing old ones. Look for ENERGY STAR certified products that use 10-50% less energy than standard models.\\n\\nPlant trees or install awnings to provide shade for your home during summer months. This can reduce cooling costs by up to 25%.\\n\\nUse ceiling fans to circulate air and make rooms feel cooler, allowing you to raise the thermostat temperature by 4Â°F without discomfort.", "source": "data/documents/tip_energy_savings.txt", "relevance_score": "medium"}, {"rank": 4, "content": "Large devices like electric vehicles, washing machines and dishwashers often support delayed start or timer functions. Schedule these devices to run outside of peak electricity pricing hours or during periods of high solar generation. Consult your device manual for specific scheduling instructions.\\n\\nElectric Vehicle Charging:\\n- Charge during off-peak hours (typically 11 PM to 6 AM) to save money\\n- Use Level 2 charging at home for faster charging when needed\\n- Set charging to complete just before you need the vehicle\\n- Consider charging during peak solar generation hours if you have solar panels\\n\\nWashing Machine Optimization:\\n- Run full loads to maximize efficiency\\n- Use cold water for most loads to save energy\\n- Schedule loads during off-peak hours or when solar generation is high\\n- Clean the machine regularly to maintain efficiency", "source": "data/documents/tip_device_best_practices.txt", "relevance_score": "medium"}]}', name='search_energy_tips', id='6d7d5ccb-58ef-4f32-8961-b5244061c76b', tool_call_id='call_hPTSEzu9N ...
#     AIMessage(content="Here are some effective energy-saving tips for running your HVAC system more efficiently:\n\n1. **Smart Thermostat Usage**:\n   - Install a smart thermostat to automatically adjust temperatures when you're away. Set it to 68°F in winter and 78°F in summer. This can save up to 10% on heating and cooling costs.\n\n2. **Regular Maintenance**:\n   - Change air filters monthly to ensure better airflow.\n   - Clean outdoor condenser coils annually to maintain efficiency.\n\n3. **Seal Air Leaks**:\n   - Use weatherstripping or caulk to seal air leaks around windows and doors. This reduces heating and cooling needs.\n\n4. **Programmable Settings**:\n   - Use programmable thermostats to adjust temperatures automatically based on your schedule, optimizing energy use during peak and off-peak hours.\n\n5. **Use Ceiling Fans**:\n   - Utilize ceiling fans to circulate air, allowing you to raise the thermostat temperature by 4°F without sacrificing comfort.\n\nBy implementing these tips, you can enhance your HVAC efficiency, reduce energy costs, and maintain a comfortable home environment.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 220, 'prompt_tokens': 1897, 'total_tokens': 2117, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAIg5JfF9SCk8ZMB9WQFk3V6TIkzi', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019c6c89-0e25-7c62-a4f2-76c9b20597ce-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1897, 'output_tokens': 220, 'total_tokens': 2117, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['search_energy_tips'],
#   'expected_response': 'The response should include specific HVAC tips like filter changes, thermostat settings, and duct sealing',
#   'timestamp': '2026-02-17T17:57:31.756217'}]

# %% [markdown]
# ## 4. Evaluate Responses

# %%
def _extract_tool_names(messages):
    tool_names = []
    for msg in messages:
        obj = msg.model_dump() if hasattr(msg, "model_dump") else {}
        name = getattr(msg, "name", None) or obj.get("name")
        if obj.get("tool_call_id") and name:
            tool_names.append(name)
    return tool_names

# %%
import re

def evaluate_response(question, final_response, expected_response):
    """
    Evaluate a single response on four dimensions:
    ACCURACY, RELEVANCE, COMPLETENESS, and USEFULNESS.
    Each dimension is scored 0.0 to 1.0.
    """
    text = (final_response or "").lower()
    question_lower = (question or "").lower()
    expected_lower = (expected_response or "").lower()

    # --- ACCURACY (0-1) ---
    # Does the response contain concrete data: numbers, units, specific times?
    accuracy_score = 0.0
    accuracy_notes = []

    has_numbers = bool(re.search(r'\d+\.?\d*', text))
    has_units = any(u in text for u in ["kwh", "kw", "$", "usd", "°f", "°c", "%"])
    has_time_refs = any(t in text for t in ["am", "pm", "midnight", "noon", "hour", "o'clock"])

    if has_numbers:
        accuracy_score += 0.4
        accuracy_notes.append("Contains numeric data")
    if has_units:
        accuracy_score += 0.3
        accuracy_notes.append("Includes measurement units")
    if has_time_refs:
        accuracy_score += 0.3
        accuracy_notes.append("References specific times")
    if not accuracy_notes:
        accuracy_notes.append("Missing concrete data points")

    # --- RELEVANCE (0-1) ---
    # Does the response address the key terms from the question?
    relevance_score = 0.0
    relevance_notes = []

    question_keywords = [w for w in re.findall(r'\b\w{4,}\b', question_lower)
                         if w not in {"should", "what", "when", "which", "would", "could", "about", "that", "this", "from", "with", "have", "your"}]
    if question_keywords:
        matched_keywords = sum(1 for kw in question_keywords if kw in text)
        relevance_score = round(min(1.0, matched_keywords / max(1, len(question_keywords) * 0.5)), 2)

    # Check alignment with expected response themes
    expected_tokens = [w for w in re.findall(r'\b\w{4,}\b', expected_lower)]
    if expected_tokens:
        matched_expected = sum(1 for t in expected_tokens[:8] if t in text)
        expected_alignment = min(1.0, matched_expected / max(1, min(len(expected_tokens), 8) * 0.4))
        relevance_score = round(min(1.0, (relevance_score + expected_alignment) / 2), 2)

    if relevance_score >= 0.7:
        relevance_notes.append("Strongly addresses the question")
    elif relevance_score >= 0.4:
        relevance_notes.append("Partially addresses the question")
    else:
        relevance_notes.append("Weak alignment with the question")

    # --- COMPLETENESS (0-1) ---
    # Is the response detailed enough with actionable guidance and reasoning?
    completeness_score = 0.0
    completeness_notes = []

    if len(text) > 300:
        completeness_score += 0.4
        completeness_notes.append("Sufficiently detailed response")
    elif len(text) > 150:
        completeness_score += 0.2
        completeness_notes.append("Moderate detail level")
    else:
        completeness_notes.append("Response may be too brief")

    action_keywords = ["recommend", "should", "schedule", "suggest", "advise", "set", "run", "charge", "avoid"]
    if any(k in text for k in action_keywords):
        completeness_score += 0.3
        completeness_notes.append("Contains actionable guidance")
    else:
        completeness_notes.append("Missing actionable guidance")

    reasoning_keywords = ["because", "since", "reason", "due to", "this means", "therefore", "result"]
    if any(k in text for k in reasoning_keywords):
        completeness_score += 0.3
        completeness_notes.append("Includes reasoning/explanation")
    else:
        completeness_notes.append("Missing reasoning")

    # --- USEFULNESS (0-1) ---
    # Does the response provide practical, usable recommendations?
    usefulness_score = 0.0
    usefulness_notes = []

    time_patterns = bool(re.search(r'\d{1,2}\s*(am|pm|:\d{2})', text))
    if time_patterns:
        usefulness_score += 0.35
        usefulness_notes.append("Provides specific time schedules")
    else:
        usefulness_notes.append("Missing specific time recommendations")

    cost_keywords = ["save", "cost", "saving", "cheaper", "expensive", "price", "$", "bill"]
    if any(k in text for k in cost_keywords):
        usefulness_score += 0.35
        usefulness_notes.append("Includes cost/savings information")
    else:
        usefulness_notes.append("Missing cost/savings context")

    practical_keywords = ["tip", "step", "first", "then", "option", "alternative", "instead"]
    if any(k in text for k in practical_keywords):
        usefulness_score += 0.3
        usefulness_notes.append("Offers practical steps or alternatives")
    else:
        usefulness_notes.append("Could offer more practical alternatives")

    overall_score = round((accuracy_score + relevance_score + completeness_score + usefulness_score) / 4, 2)

    return {
        "accuracy": round(accuracy_score, 2),
        "relevance": round(relevance_score, 2),
        "completeness": round(completeness_score, 2),
        "usefulness": round(usefulness_score, 2),
        "overall": overall_score,
        "passed": overall_score >= 0.5,
        "notes": {
            "accuracy": accuracy_notes,
            "relevance": relevance_notes,
            "completeness": completeness_notes,
            "usefulness": usefulness_notes,
        },
    }

# %%
def evaluate_tool_usage(messages, expected_tools):
    """Evaluate if the right tools were used."""
    used_tools = _extract_tool_names(messages)
    used_set = set(used_tools)
    expected_set = set(expected_tools or [])

    matched = sorted(list(expected_set.intersection(used_set)))
    missing = sorted(list(expected_set - used_set))
    extra = sorted(list(used_set - expected_set))

    precision = len(matched) / max(1, len(used_set))
    recall = len(matched) / max(1, len(expected_set))
    f1 = (2 * precision * recall / (precision + recall)) if (precision + recall) else 0

    return {
        "used_tools": used_tools,
        "expected_tools": list(expected_set),
        "matched": matched,
        "missing": missing,
        "extra": extra,
        "precision": round(precision, 2),
        "recall": round(recall, 2),
        "f1": round(f1, 2),
        "passed": recall >= 0.7,
    }

# %%
def generate_evaluation_report():
    """Generate evaluation metrics across all test_results with overall scores."""
    report_rows = []
    all_tools_used = set()
    all_tools_expected = set()

    for result in test_results:
        if isinstance(result.get("response"), dict):
            messages = result["response"].get("messages", [])
            final_response = messages[-1].content if messages else ""
        else:
            messages = []
            final_response = str(result.get("response", ""))

        response_eval = evaluate_response(
            question=result["question"],
            final_response=final_response,
            expected_response=result["expected_response"],
        )
        tool_eval = evaluate_tool_usage(messages, result["expected_tools"])

        all_tools_used.update(tool_eval["used_tools"])
        all_tools_expected.update(tool_eval["expected_tools"])

        report_rows.append({
            "test_id": result["test_id"],
            "accuracy": response_eval["accuracy"],
            "relevance": response_eval["relevance"],
            "completeness": response_eval["completeness"],
            "usefulness": response_eval["usefulness"],
            "overall": response_eval["overall"],
            "response_passed": response_eval["passed"],
            "tool_f1": tool_eval["f1"],
            "tool_recall": tool_eval["recall"],
            "tool_passed": tool_eval["passed"],
            "used_tools": tool_eval["used_tools"],
            "missing_tools": tool_eval["missing"],
        })

    total = len(report_rows)

    # Overall scores across all tests
    avg_accuracy = round(sum(r["accuracy"] for r in report_rows) / max(1, total), 2)
    avg_relevance = round(sum(r["relevance"] for r in report_rows) / max(1, total), 2)
    avg_completeness = round(sum(r["completeness"] for r in report_rows) / max(1, total), 2)
    avg_usefulness = round(sum(r["usefulness"] for r in report_rows) / max(1, total), 2)
    avg_overall = round(sum(r["overall"] for r in report_rows) / max(1, total), 2)
    avg_tool_f1 = round(sum(r["tool_f1"] for r in report_rows) / max(1, total), 2)
    pass_rate = round(sum(1 for r in report_rows if r["response_passed"] and r["tool_passed"]) / max(1, total), 2)

    # Tool coverage
    tool_coverage = sorted(all_tools_used)
    missing_from_any = sorted(all_tools_expected - all_tools_used)

    summary = {
        "total_tests": total,
        "overall_scores": {
            "accuracy": avg_accuracy,
            "relevance": avg_relevance,
            "completeness": avg_completeness,
            "usefulness": avg_usefulness,
            "combined_overall": avg_overall,
        },
        "tool_metrics": {
            "avg_tool_f1": avg_tool_f1,
            "tools_used": tool_coverage,
            "tools_never_called": missing_from_any,
        },
        "pass_rate": pass_rate,
        "failed_tests": [r["test_id"] for r in report_rows if not (r["response_passed"] and r["tool_passed"])],
        "details": report_rows,
    }

    return summary

# %%
# Generate and display the evaluation report
evaluation_report = generate_evaluation_report()

# --- Overall Combined Scores ---
print("=" * 60)
print("         OVERALL EVALUATION SCORES (All Test Cases)")
print("=" * 60)
scores = evaluation_report["overall_scores"]
print(f"  Accuracy:      {scores['accuracy']:.2f} / 1.00")
print(f"  Relevance:     {scores['relevance']:.2f} / 1.00")
print(f"  Completeness:  {scores['completeness']:.2f} / 1.00")
print(f"  Usefulness:    {scores['usefulness']:.2f} / 1.00")
print(f"  ---")
print(f"  Combined Overall Score:  {scores['combined_overall']:.2f} / 1.00")
print(f"  Overall Pass Rate:       {evaluation_report['pass_rate']:.0%}")

# --- Tool Coverage ---
tools = evaluation_report["tool_metrics"]
print(f"\n  Tool F1 (avg):  {tools['avg_tool_f1']:.2f}")
print(f"  Tools Used:     {', '.join(tools['tools_used'])}")
if tools["tools_never_called"]:
    print(f"  Tools Missing:  {', '.join(tools['tools_never_called'])}")
else:
    print(f"  Tools Missing:  None — all expected tools were called")

# --- Per-Test Breakdown ---
print("\n" + "=" * 60)
print("         PER-TEST BREAKDOWN")
print("=" * 60)
print(f"{'Test ID':<18} {'Acc':>5} {'Rel':>5} {'Comp':>5} {'Use':>5} {'Overall':>8} {'Tools':>6} {'Status':>7}")
print("-" * 60)
for d in evaluation_report["details"]:
    status = "PASS" if d["response_passed"] and d["tool_passed"] else "FAIL"
    print(f"{d['test_id']:<18} {d['accuracy']:>5.2f} {d['relevance']:>5.2f} {d['completeness']:>5.2f} {d['usefulness']:>5.2f} {d['overall']:>8.2f} {d['tool_f1']:>6.2f} {status:>7}")

if evaluation_report["failed_tests"]:
    print(f"\nFailed: {', '.join(evaluation_report['failed_tests'])}")

# --- Strengths ---
print("\n" + "=" * 60)
print("         STRENGTHS")
print("=" * 60)
strengths = []
if scores["accuracy"] >= 0.7:
    strengths.append("High accuracy: responses consistently include concrete data (numbers, units, specific times).")
if scores["relevance"] >= 0.7:
    strengths.append("Strong relevance: responses directly address user questions and align with expected outcomes.")
if scores["completeness"] >= 0.6:
    strengths.append("Good completeness: responses are detailed with actionable guidance and reasoning.")
if scores["usefulness"] >= 0.6:
    strengths.append("Practical usefulness: responses include specific schedules and cost/savings estimates.")
if tools["avg_tool_f1"] >= 0.7:
    strengths.append("Effective tool usage: the agent selects appropriate tools for each query with high F1.")
if not tools["tools_never_called"]:
    strengths.append("Full tool coverage: all available tools are exercised across the test suite.")
if not strengths:
    strengths.append("The agent produces functional responses for all test cases without errors.")
for s in strengths:
    print(f"  + {s}")

# --- Weaknesses ---
print("\n" + "=" * 60)
print("         WEAKNESSES")
print("=" * 60)
weaknesses = []
if scores["accuracy"] < 0.7:
    weaknesses.append("Accuracy could improve: some responses lack specific numbers or measurable data points.")
if scores["relevance"] < 0.7:
    weaknesses.append("Relevance gaps: some responses drift from the core question or miss expected themes.")
if scores["completeness"] < 0.6:
    weaknesses.append("Completeness issues: some responses are brief or lack reasoning for recommendations.")
if scores["usefulness"] < 0.6:
    weaknesses.append("Usefulness gaps: some responses miss specific time schedules or cost estimates.")
if tools["avg_tool_f1"] < 0.7:
    weaknesses.append(f"Tool selection imprecise: average F1 is {tools['avg_tool_f1']:.2f}; agent sometimes skips expected tools or calls extra ones.")
if tools["tools_never_called"]:
    weaknesses.append(f"Some tools never called: {', '.join(tools['tools_never_called'])}.")
if not weaknesses:
    weaknesses.append("No significant weaknesses identified at current thresholds.")
for w in weaknesses:
    print(f"  - {w}")

# --- Recommendations for Improvement ---
print("\n" + "=" * 60)
print("         RECOMMENDATIONS FOR IMPROVEMENT")
print("=" * 60)
recommendations = [
    "1. Enhance the system prompt to explicitly instruct the agent to use the savings calculator tool when comparing usage scenarios, so it provides precise dollar estimates rather than rough approximations.",
    "2. Add prompt guidance for the agent to always check weather forecasts alongside electricity prices for thermostat and HVAC questions, since weather conditions directly affect optimal setpoints.",
    "3. Encourage the agent to cross-reference historical usage data with energy-saving tips (RAG) when giving reduction advice, ensuring recommendations are personalized to the user's actual patterns.",
    "4. Consider adding few-shot examples to the system prompt demonstrating ideal tool combinations for common query types (e.g., EV charging should use weather + pricing + savings calculator).",
    "5. Expand the test suite to cover edge cases such as cloudy-day solar queries, multi-day scheduling, and conflicting optimization goals (cost vs. comfort vs. carbon).",
]
for r in recommendations:
    print(f"  {r}")

print("\n" + "=" * 60)
# Out:
# ============================================================
#          OVERALL EVALUATION SCORES (All Test Cases)
# ============================================================
#   Accuracy:      0.95 / 1.00
#   Relevance:     0.96 / 1.00
#   Completeness:  0.88 / 1.00
#   Usefulness:    0.64 / 1.00
#   ---
#   Combined Overall Score:  0.86 / 1.00
#   Overall Pass Rate:       83%
#
#   Tool F1 (avg):  0.85
#   Tools Used:     calculate_energy_savings, get_electricity_prices, get_recent_energy_summary, get_weather_forecast, query_energy_usage, query_solar_generation, search_energy_tips
#   Tools Missing:  None — all expected tools were called
#
# ============================================================
#          PER-TEST BREAKDOWN
# ============================================================
# Test ID              Acc   Rel  Comp   Use  Overall  Tools  Status
# ------------------------------------------------------------
# ev_charging_1       1.00  0.97  1.00  0.70     0.92   1.00    PASS
# ev_charging_2       1.00  0.97  1.00  0.70     0.92   0.67    FAIL
# thermostat_1        1.00  1.00  1.00  0.70     0.93   1.00    PASS
# thermostat_2        1.00  0.97  1.00  0.70     0.92   1.00    PASS
# appliance_1         1.00  1.00  1.00  0.70     0.93   0.67    PASS
# appliance_2         1.00  0.86  1.00  0.70     0.89   0.67    PASS
# solar_1             0.70  0.97  1.00  0.70     0.84   1.00    PASS
# solar_2             1.00  1.00  0.70  0.70     0.85   1.00    PASS
# history_1           1.00  1.00  1.00  0.70     0.93   0.50    FAIL
# savings_1           0.70  0.86  0.70  0.35     0.65   0.67    PASS
# summary_1           1.00  1.00  0.40  0.35     0.69   1.00    PASS
# tips_1              1.00  0.97  0.70  0.65     0.83   1.00    PASS
#
# Failed: ev_charging_2, history_1
#
# ============================================================
#          STRENGTHS
# ============================================================
#   + High accuracy: responses consistently include concrete data (numbers, units, specific times).
#   + Strong relevance: responses directly address user questions and align with expected outcomes.
#   + Good completeness: responses are detailed with actionable guidance and reasoning.
#   + Practical usefulness: responses include specific schedules and cost/savings estimates.
#   + Effective tool usage: the agent selects appropriate tools for each query with high F1.
#   + Full tool coverage: all available tools are exercised across the test suite.
#
# ============================================================
#          WEAKNESSES
# ============================================================
#   - No significant weaknesses identified at current thresholds.
#
# ============================================================
#          RECOMMENDATIONS FOR IMPROVEMENT
# ============================================================
#   1. Enhance the system prompt to explicitly instruct the agent to use the savings calculator tool when comparing usage scenarios, so it provides precise dollar estimates rather than rough approximations.
#   2. Add prompt guidance for the agent to always check weather forecasts alongside electricity prices for thermostat and HVAC questions, since weather conditions directly affect optimal setpoints.
#   3. Encourage the agent to cross-reference historical usage data with energy-saving tips (RAG) when giving reduction advice, ensuring recommendations are personalized to the user's actual patterns.
#   4. Consider adding few-shot examples to the system prompt demonstrating ideal tool combinations for common query types (e.g., EV charging should use weather + pricing + savings calculator).
#   5. Expand the test suite to cover edge cases such as cloudy-day solar queries, multi-day scheduling, and conflicting optimization goals (cost vs. comfort vs. carbon).
#
# ============================================================
